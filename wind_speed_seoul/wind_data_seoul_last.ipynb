# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (8,284 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 994 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 15.4 MB 38 kB/s
# ...
#      |████████████████████████████████| 6.3 MB 49.0 MB/s
# ...

# %% [markdown]
# # 초기 설정

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
import folium
import geopandas as gpd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.rcParams["font.family"] = "NanumGothic"
plt.rcParams["figure.figsize"] = (10,10)

# %%
line = ['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월']

# %% [markdown]
# # 서울시 풍속 데이터

# %%
wind_file = "/content/drive/MyDrive/빅캠공모전_data/TL_WIND_SPEED_AVG_2017.shp"
wind = gpd.read_file(wind_file)
wind
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 0    1.7  2.1  2.7  ...  556471.835  01(풍속평균).shp  POINT (194349.346 556471.835)
# 1    1.6  1.9  2.3  ...  539796.939  01(풍속평균).shp  POINT (192586.637 539796.939)
# 2    1.2  1.2  1.5  ...  563251.524  01(풍속평균).shp  POINT (203801.837 563251.524)
# 3    0.0  2.0  2.4  ...  555971.977  01(풍속평균).shp  POINT (193704.957 555971.977)
# 4    0.0  1.9  2.6  ...  549294.842  01(풍속평균).shp  POINT (194185.402 549294.842)
# ..   ...  ...  ...  ...         ...           ...                            ...
# 490  1.1  1.3  1.3  ...  544549.000  01(풍속평균).shp  POINT (197923.000 544549.000)
# 491  1.4  1.5  1.4  ...  543347.016  01(풍속평균).shp  POINT (195419.224 543347.016)
# 492  1.4  2.0  1.7  ...  550069.424  01(풍속평균).shp  POINT (186746.370 550069.424)
# 493  1.9  2.2  2.1  ...  549504.437  01(풍속평균).shp  POINT (203587.734 549504.437)
# 494  1.7  1.7  1.6  ...  553500.000  01(풍속평균).shp  POINT (193818.000 553500.000)
#
# ...

# %% [markdown]
# # 강동구

# %%
wind_gangdong = wind[wind["ADDR_KOR"].str.contains('강동구')]
wind_gangdong
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 44   1.0  1.1  1.3  ...  550254.454  01(풍속평균).shp  POINT (213102.887 550254.454)
# 91   2.0  2.2  2.7  ...  547782.257  01(풍속평균).shp  POINT (211056.360 547782.257)
# 96   1.1  1.1  1.5  ...  550254.454  01(풍속평균).shp  POINT (213102.887 550254.454)
# 104  2.1  2.2  2.6  ...  547782.257  01(풍속평균).shp  POINT (211056.360 547782.257)
# 159  0.0  1.9  2.4  ...  547782.257  01(풍속평균).shp  POINT (211056.360 547782.257)
# 164  0.0  1.2  1.5  ...  550254.454  01(풍속평균).shp  POINT (213102.887 550254.454)
# 211  1.9  2.0  2.5  ...  547782.257  01(풍속평균).shp  POINT (211056.360 547782.257)
# 215  1.2  1.5  1.8  ...  550254.454  01(풍속평균).shp  POINT (213102.887 550254.454)
# 259  1.6  1.8  2.1  ...  547782.257  01(풍속평균).shp  POINT (211056.360 547782.257)
# 264  1.1  1.1  1.2  ...  550254.454  01(풍속평균).shp  POINT (213102.887 550254.454)
# 317  1.9  2.1  1.7  ...  547782.257  01(풍속평균).shp  POINT (211056.360 547782.257)
# ...

# %%
#강동구 월별 평균 리스트
wind_gangdong_avg = []

# %% [markdown]
# ## 1월

# %%
wind_gangdong_01 = wind_gangdong['M01']
wind_gangdong_01_list = wind_gangdong_01.tolist()

res = 0
for i in wind_gangdong_01_list:
  res+=i

avg_gangdong_01 = round(res/(len(wind_gangdong_01_list)),2)
wind_gangdong_avg.append(avg_gangdong_01)

# %% [markdown]
# ## 2월

# %%
wind_gangdong_02 = wind_gangdong['M02']
wind_gangdong_02_list = wind_gangdong_02.tolist()

res = 0
for i in wind_gangdong_02_list:
  res+=i

avg_gangdong_02 = round(res/(len(wind_gangdong_02_list)),2)
wind_gangdong_avg.append(avg_gangdong_02)

# %% [markdown]
# ## 3월

# %%
wind_gangdong_03 = wind_gangdong['M03']
wind_gangdong_03_list = wind_gangdong_03.tolist()

res = 0
for i in wind_gangdong_03_list:
  res+=i

avg_gangdong_03 = round(res/(len(wind_gangdong_03_list)),2)
wind_gangdong_avg.append(avg_gangdong_03)

# %% [markdown]
# ## 4월

# %%
wind_gangdong_04 = wind_gangdong['M04']
wind_gangdong_04_list = wind_gangdong_04.tolist()

res = 0
for i in wind_gangdong_04_list:
  res+=i

avg_gangdong_04 = round(res/(len(wind_gangdong_04_list)),2)
wind_gangdong_avg.append(avg_gangdong_04)

# %% [markdown]
# ## 5월

# %%
wind_gangdong_05 = wind_gangdong['M05']
wind_gangdong_05_list = wind_gangdong_05.tolist()

res = 0
for i in wind_gangdong_05_list:
  res+=i

avg_gangdong_05 = round(res/(len(wind_gangdong_05_list)),2)
wind_gangdong_avg.append(avg_gangdong_05)

# %% [markdown]
# ## 6월

# %%
wind_gangdong_06 = wind_gangdong['M06']
wind_gangdong_06_list = wind_gangdong_06.tolist()

res = 0
for i in wind_gangdong_06_list:
  res+=i

avg_gangdong_06 = round(res/(len(wind_gangdong_06_list)),2)
wind_gangdong_avg.append(avg_gangdong_06)

# %% [markdown]
# ## 7월

# %%
wind_gangdong_07 = wind_gangdong['M07']
wind_gangdong_07_list = wind_gangdong_07.tolist()

res = 0
for i in wind_gangdong_07_list:
  res+=i

avg_gangdong_07 = round(res/(len(wind_gangdong_07_list)),2)
wind_gangdong_avg.append(avg_gangdong_07)

# %% [markdown]
# ## 8월

# %%
wind_gangdong_08 = wind_gangdong['M08']
wind_gangdong_08_list = wind_gangdong_08.tolist()

res = 0
for i in wind_gangdong_08_list:
  res+=i

avg_gangdong_08 = round(res/(len(wind_gangdong_08_list)),2)
wind_gangdong_avg.append(avg_gangdong_08)

# %% [markdown]
# ## 9월

# %%
wind_gangdong_09 = wind_gangdong['M09']
wind_gangdong_09_list = wind_gangdong_09.tolist()

res = 0
for i in wind_gangdong_09_list:
  res+=i

avg_gangdong_09 = round(res/(len(wind_gangdong_09_list)),2)
wind_gangdong_avg.append(avg_gangdong_09)

# %% [markdown]
# ## 10월

# %%
wind_gangdong_10 = wind_gangdong['M10']
wind_gangdong_10_list = wind_gangdong_10.tolist()

res = 0
for i in wind_gangdong_10_list:
  res+=i

avg_gangdong_10 = round(res/(len(wind_gangdong_10_list)),2)
wind_gangdong_avg.append(avg_gangdong_10)

# %% [markdown]
# ## 11월

# %%
wind_gangdong_11 = wind_gangdong['M11']
wind_gangdong_11_list = wind_gangdong_11.tolist()

res = 0
for i in wind_gangdong_11_list:
  res+=i

avg_gangdong_11 = round(res/(len(wind_gangdong_11_list)),2)
wind_gangdong_avg.append(avg_gangdong_11)

# %% [markdown]
# ## 12월

# %%
wind_gangdong_12 = wind_gangdong['M12']
wind_gangdong_12_list = wind_gangdong_12.tolist()

res = 0
for i in wind_gangdong_12_list:
  res+=i

avg_gangdong_12 = round(res/(len(wind_gangdong_12_list)),2)
wind_gangdong_avg.append(avg_gangdong_12)

# %%
print("강동구 1월~12월 평균 풍속: {}".format(wind_gangdong_avg))
# Out:
# 강동구 1월~12월 평균 풍속: [1.29, 1.61, 1.8, 1.79, 1.69, 1.57, 1.58, 1.57, 1.48, 1.4, 1.5, 1.36]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_gangdong_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('강동구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 송파구

# %%
wind_songpa = wind[wind["ADDR_KOR"].str.contains('송파구')]
wind_songpa
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 31   1.1  1.2  1.5  ...  544829.740  01(풍속평균).shp  POINT (211325.276 544829.740)
# 45   1.9  1.5  2.1  ...  545425.109  01(풍속평균).shp  POINT (208876.127 545425.109)
# 82   1.1  1.2  1.5  ...  544829.740  01(풍속평균).shp  POINT (211325.276 544829.740)
# 97   1.8  1.9  2.0  ...  545425.109  01(풍속평균).shp  POINT (208876.127 545425.109)
# 151  0.0  1.1  1.5  ...  544829.740  01(풍속평균).shp  POINT (211325.276 544829.740)
# 165  0.0  1.4  2.0  ...  545425.109  01(풍속평균).shp  POINT (208876.127 545425.109)
# 202  1.0  1.2  1.4  ...  544829.740  01(풍속평균).shp  POINT (211325.276 544829.740)
# 216  1.6  1.6  1.8  ...  545425.109  01(풍속평균).shp  POINT (208876.127 545425.109)
# 251  1.0  1.1  1.2  ...  544829.740  01(풍속평균).shp  POINT (211325.276 544829.740)
# 265  1.5  1.5  1.5  ...  545425.109  01(풍속평균).shp  POINT (208876.127 545425.109)
# 305  1.6  1.5  1.8  ...  545425.109  01(풍속평균).shp  POINT (208876.127 545425.109)
# ...

# %%
#송파구 월별 평균 리스트
wind_songpa_avg = []

# %% [markdown]
# ## 1월

# %%
wind_songpa_01 = wind_songpa['M01']
wind_songpa_01_list = wind_songpa_01.tolist()

res = 0
for i in wind_songpa_01_list:
  res+=i

avg_songpa_01 = round(res/(len(wind_songpa_01_list)),2)
wind_songpa_avg.append(avg_songpa_01)

# %%
wind_songpa_avg
# Out:
# [1.16]

# %% [markdown]
# ## 2월

# %%
wind_songpa_02 = wind_songpa['M02']
wind_songpa_02_list = wind_songpa_02.tolist()

res = 0
for i in wind_songpa_02_list:
  res+=i

avg_songpa_02 = round(res/(len(wind_songpa_02_list)),2)
wind_songpa_avg.append(avg_songpa_02)

# %% [markdown]
# ## 3월

# %%
wind_songpa_03 = wind_songpa['M03']
wind_songpa_03_list = wind_songpa_03.tolist()

res = 0
for i in wind_songpa_03_list:
  res+=i

avg_songpa_03 = round(res/(len(wind_songpa_03_list)),2)
wind_songpa_avg.append(avg_songpa_03)

# %% [markdown]
# ## 4월

# %%
wind_songpa_04 = wind_songpa['M04']
wind_songpa_04_list = wind_songpa_04.tolist()

res = 0
for i in wind_songpa_04_list:
  res+=i

avg_songpa_04 = round(res/(len(wind_songpa_04_list)),2)
wind_songpa_avg.append(avg_songpa_04)

# %% [markdown]
# ## 5월

# %%
wind_songpa_05 = wind_songpa['M05']
wind_songpa_05_list = wind_songpa_05.tolist()

res = 0
for i in wind_songpa_05_list:
  res+=i

avg_songpa_05 = round(res/(len(wind_songpa_05_list)),2)
wind_songpa_avg.append(avg_songpa_05)

# %% [markdown]
# ## 6월

# %%
wind_songpa_06 = wind_songpa['M06']
wind_songpa_06_list = wind_songpa_06.tolist()

res = 0
for i in wind_songpa_06_list:
  res+=i

avg_songpa_06 = round(res/(len(wind_songpa_06_list)),2)
wind_songpa_avg.append(avg_songpa_06)

# %% [markdown]
# ## 7월

# %%
wind_songpa_07 = wind_songpa['M07']
wind_songpa_07_list = wind_songpa_07.tolist()

res = 0
for i in wind_songpa_07_list:
  res+=i

avg_songpa_07 = round(res/(len(wind_songpa_07_list)),2)
wind_songpa_avg.append(avg_songpa_07)

# %% [markdown]
# ## 8월

# %%
wind_songpa_08 = wind_songpa['M08']
wind_songpa_08_list = wind_songpa_08.tolist()

res = 0
for i in wind_songpa_08_list:
  res+=i

avg_songpa_08 = round(res/(len(wind_songpa_08_list)),2)
wind_songpa_avg.append(avg_songpa_08)

# %% [markdown]
# ## 9월

# %%
wind_songpa_09 = wind_songpa['M09']
wind_songpa_09_list = wind_songpa_09.tolist()

res = 0
for i in wind_songpa_09_list:
  res+=i

avg_songpa_09 = round(res/(len(wind_songpa_09_list)),2)
wind_songpa_avg.append(avg_songpa_09)

# %% [markdown]
# ## 10월

# %%
wind_songpa_10 = wind_songpa['M10']
wind_songpa_10_list = wind_songpa_10.tolist()

res = 0
for i in wind_songpa_10_list:
  res+=i

avg_songpa_10 = round(res/(len(wind_songpa_10_list)),2)
wind_songpa_avg.append(avg_songpa_10)

# %% [markdown]
# ## 11월

# %%
wind_songpa_11 = wind_songpa['M11']
wind_songpa_11_list = wind_songpa_11.tolist()

res = 0
for i in wind_songpa_11_list:
  res+=i

avg_songpa_11 = round(res/(len(wind_songpa_11_list)),2)
wind_songpa_avg.append(avg_songpa_11)

# %% [markdown]
# ## 12월

# %%
wind_songpa_12 = wind_songpa['M12']
wind_songpa_12_list = wind_songpa_12.tolist()

res = 0
for i in wind_songpa_12_list:
  res+=i

avg_songpa_12 = round(res/(len(wind_songpa_12_list)),2)
wind_songpa_avg.append(avg_songpa_12)

# %%
print("송파구 1월~12월 평균 풍속: {}".format(wind_songpa_avg))
# Out:
# 송파구 1월~12월 평균 풍속: [1.16, 1.4, 1.59, 1.56, 1.52, 1.41, 1.46, 1.39, 1.22, 1.18, 1.37, 1.23]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_songpa_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('송파구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 강남구

# %%
wind_gangnam = wind[wind["ADDR_KOR"].str.contains('강남구')]
wind_gangnam
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 24   1.6  1.3  1.8  ...  546485.279  01(풍속평균).shp  POINT (204242.661 546485.279)
# 42   1.8  1.6  2.1  ...  545528.746  01(풍속평균).shp  POINT (204270.161 545528.746)
# 76   1.4  1.5  1.5  ...  546485.279  01(풍속평균).shp  POINT (204242.661 546485.279)
# 94   1.6  1.8  2.0  ...  545528.746  01(풍속평균).shp  POINT (204270.161 545528.746)
# 135  1.2  1.4  1.5  ...  546485.279  01(풍속평균).shp  POINT (204242.661 546485.279)
# 144  1.2  1.3  1.6  ...  546485.279  01(풍속평균).shp  POINT (204242.661 546485.279)
# 162  0.0  1.5  2.0  ...  545528.746  01(풍속평균).shp  POINT (204270.161 545528.746)
# 196  1.3  1.3  1.4  ...  546485.279  01(풍속평균).shp  POINT (204242.661 546485.279)
# 214  1.6  1.7  2.0  ...  545528.746  01(풍속평균).shp  POINT (204270.161 545528.746)
# 244  1.0  1.1  1.2  ...  546485.279  01(풍속평균).shp  POINT (204242.661 546485.279)
# 262  1.7  1.8  1.9  ...  545528.746  01(풍속평균).shp  POINT (204270.161 545528.746)
# ...

# %%
#강남구 월별 평균 리스트
wind_gangnam_avg = []

# %% [markdown]
# ## 1월

# %%
wind_gangnam_01 = wind_gangnam['M01']
wind_gangnam_01_list = wind_gangnam_01.tolist()

res = 0
for i in wind_gangnam_01_list:
  res+=i

avg_gangnam_01 = round(res/(len(wind_gangnam_01_list)),2)
wind_gangnam_avg.append(avg_gangnam_01)

# %% [markdown]
# ## 2월

# %%
wind_gangnam_02 = wind_gangnam['M02']
wind_gangnam_02_list = wind_gangnam_02.tolist()

res = 0
for i in wind_gangnam_02_list:
  res+=i

avg_gangnam_02 = round(res/(len(wind_gangnam_02_list)),2)
wind_gangnam_avg.append(avg_gangnam_02)

# %% [markdown]
# ## 3월

# %%
wind_gangnam_03 = wind_gangnam['M03']
wind_gangnam_03_list = wind_gangnam_03.tolist()

res = 0
for i in wind_gangnam_03_list:
  res+=i

avg_gangnam_03 = round(res/(len(wind_gangnam_03_list)),2)
wind_gangnam_avg.append(avg_gangnam_03)

# %% [markdown]
# ## 4월

# %%
wind_gangnam_04 = wind_gangnam['M04']
wind_gangnam_04_list = wind_gangnam_04.tolist()

res = 0
for i in wind_gangnam_04_list:
  res+=i

avg_gangnam_04 = round(res/(len(wind_gangnam_04_list)),2)
wind_gangnam_avg.append(avg_gangnam_04)

# %% [markdown]
# ## 5월

# %%
wind_gangnam_05 = wind_gangnam['M05']
wind_gangnam_05_list = wind_gangnam_05.tolist()

res = 0
for i in wind_gangnam_05_list:
  res+=i

avg_gangnam_05 = round(res/(len(wind_gangnam_05_list)),2)
wind_gangnam_avg.append(avg_gangnam_05)

# %% [markdown]
# ## 6월

# %%
wind_gangnam_06 = wind_gangnam['M06']
wind_gangnam_06_list = wind_gangnam_06.tolist()

res = 0
for i in wind_gangnam_06_list:
  res+=i

avg_gangnam_06 = round(res/(len(wind_gangnam_06_list)),2)
wind_gangnam_avg.append(avg_gangnam_06)

# %% [markdown]
# ## 7월

# %%
wind_gangnam_07 = wind_gangnam['M07']
wind_gangnam_07_list = wind_gangnam_07.tolist()

res = 0
for i in wind_gangnam_07_list:
  res+=i

avg_gangnam_07 = round(res/(len(wind_gangnam_07_list)),2)
wind_gangnam_avg.append(avg_gangnam_07)

# %% [markdown]
# ## 8월

# %%
wind_gangnam_08 = wind_gangnam['M08']
wind_gangnam_08_list = wind_gangnam_08.tolist()

res = 0
for i in wind_gangnam_08_list:
  res+=i

avg_gangnam_08 = round(res/(len(wind_gangnam_08_list)),2)
wind_gangnam_avg.append(avg_gangnam_08)

# %% [markdown]
# ## 9월

# %%
wind_gangnam_09 = wind_gangnam['M09']
wind_gangnam_09_list = wind_gangnam_09.tolist()

res = 0
for i in wind_gangnam_09_list:
  res+=i

avg_gangnam_09 = round(res/(len(wind_gangnam_09_list)),2)
wind_gangnam_avg.append(avg_gangnam_09)

# %% [markdown]
# ## 10월

# %%
wind_gangnam_10 = wind_gangnam['M10']
wind_gangnam_10_list = wind_gangnam_10.tolist()

res = 0
for i in wind_gangnam_10_list:
  res+=i

avg_gangnam_10 = round(res/(len(wind_gangnam_10_list)),2)
wind_gangnam_avg.append(avg_gangnam_10)

# %% [markdown]
# ## 11월

# %%
wind_gangnam_11 = wind_gangnam['M11']
wind_gangnam_11_list = wind_gangnam_11.tolist()

res = 0
for i in wind_gangnam_11_list:
  res+=i

avg_gangnam_11 = round(res/(len(wind_gangnam_11_list)),2)
wind_gangnam_avg.append(avg_gangnam_11)

# %% [markdown]
# ## 12월

# %%
wind_gangnam_12 = wind_gangnam['M12']
wind_gangnam_12_list = wind_gangnam_12.tolist()

res = 0
for i in wind_gangnam_12_list:
  res+=i

avg_gangnam_12 = round(res/(len(wind_gangnam_12_list)),2)
wind_gangnam_avg.append(avg_gangnam_12)

# %%
print("강남구 1월~12월 평균 풍속: {}".format(wind_gangnam_avg))
# Out:
# 강남구 1월~12월 평균 풍속: [1.36, 1.52, 1.65, 1.54, 1.43, 1.35, 1.25, 1.22, 1.17, 1.23, 1.38, 1.32]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_gangnam_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('강남구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 서초구

# %%
wind_seocho = wind[wind["ADDR_KOR"].str.contains('서초구')]
wind_seocho
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 7    1.3  1.4  1.6  ...  542290.757  01(풍속평균).shp  POINT (201768.523 542290.757)
# 43   1.6  1.2  1.9  ...  542290.757  01(풍속평균).shp  POINT (201768.523 542290.757)
# 75   1.5  1.7  1.9  ...  542250.284  01(풍속평균).shp  POINT (198726.726 542250.284)
# 95   1.4  1.5  1.8  ...  542290.757  01(풍속평균).shp  POINT (201768.523 542290.757)
# 103  1.9  1.5  2.0  ...  542250.284  01(풍속평균).shp  POINT (198726.726 542250.284)
# 134  1.3  1.6  1.7  ...  542250.284  01(풍속평균).shp  POINT (198726.726 542250.284)
# 143  1.8  1.8  2.2  ...  542250.284  01(풍속평균).shp  POINT (198726.726 542250.284)
# 163  0.0  1.3  1.8  ...  542290.757  01(풍속평균).shp  POINT (201768.523 542290.757)
# 195  1.9  1.8  2.0  ...  542250.284  01(풍속평균).shp  POINT (198726.726 542250.284)
# 243  1.7  1.8  1.9  ...  542250.284  01(풍속평균).shp  POINT (198726.726 542250.284)
# 263  1.4  1.5  1.6  ...  542290.757  01(풍속평균).shp  POINT (201768.523 542290.757)
# ...

# %%
#서초구 월별 평균 리스트
wind_seocho_avg = []

# %% [markdown]
# ## 1월

# %%
wind_seocho_01 = wind_seocho['M01']
wind_seocho_01_list = wind_seocho_01.tolist()

res = 0
for i in wind_seocho_01_list:
  res+=i

avg_seocho_01 = round(res/(len(wind_seocho_01_list)),2)
wind_seocho_avg.append(avg_seocho_01)

# %% [markdown]
# ## 2월

# %%
wind_seocho_02 = wind_seocho['M02']
wind_seocho_02_list = wind_seocho_02.tolist()

res = 0
for i in wind_seocho_02_list:
  res+=i

avg_seocho_02 = round(res/(len(wind_seocho_02_list)),2)
wind_seocho_avg.append(avg_seocho_02)

# %% [markdown]
# ## 3월

# %%
wind_seocho_03 = wind_seocho['M03']
wind_seocho_03_list = wind_seocho_03.tolist()

res = 0
for i in wind_seocho_03_list:
  res+=i

avg_seocho_03 = round(res/(len(wind_seocho_03_list)),2)
wind_seocho_avg.append(avg_seocho_03)

# %% [markdown]
# ## 4월

# %%
wind_seocho_04 = wind_seocho['M04']
wind_seocho_04_list = wind_seocho_04.tolist()

res = 0
for i in wind_seocho_04_list:
  res+=i

avg_seocho_04 = round(res/(len(wind_seocho_04_list)),2)
wind_seocho_avg.append(avg_seocho_04)

# %% [markdown]
# ## 5월

# %%
wind_seocho_05 = wind_seocho['M05']
wind_seocho_05_list = wind_seocho_05.tolist()

res = 0
for i in wind_seocho_05_list:
  res+=i

avg_seocho_05 = round(res/(len(wind_seocho_05_list)),2)
wind_seocho_avg.append(avg_seocho_05)

# %% [markdown]
# ## 6월

# %%
wind_seocho_06 = wind_seocho['M06']
wind_seocho_06_list = wind_seocho_06.tolist()

res = 0
for i in wind_seocho_06_list:
  res+=i

avg_seocho_06 = round(res/(len(wind_seocho_06_list)),2)
wind_seocho_avg.append(avg_seocho_06)

# %% [markdown]
# ## 7월

# %%
wind_seocho_07 = wind_seocho['M07']
wind_seocho_07_list = wind_seocho_07.tolist()

res = 0
for i in wind_seocho_07_list:
  res+=i

avg_seocho_07 = round(res/(len(wind_seocho_07_list)),2)
wind_seocho_avg.append(avg_seocho_07)

# %% [markdown]
# ## 8월

# %%
wind_seocho_08 = wind_seocho['M08']
wind_seocho_08_list = wind_seocho_08.tolist()

res = 0
for i in wind_seocho_08_list:
  res+=i

avg_seocho_08 = round(res/(len(wind_seocho_08_list)),2)
wind_seocho_avg.append(avg_seocho_08)

# %% [markdown]
# ## 9월

# %%
wind_seocho_09 = wind_seocho['M09']
wind_seocho_09_list = wind_seocho_09.tolist()

res = 0
for i in wind_seocho_09_list:
  res+=i

avg_seocho_09 = round(res/(len(wind_seocho_09_list)),2)
wind_seocho_avg.append(avg_seocho_09)

# %% [markdown]
# ## 10월

# %%
wind_seocho_10 = wind_seocho['M10']
wind_seocho_10_list = wind_seocho_10.tolist()

res = 0
for i in wind_seocho_10_list:
  res+=i

avg_seocho_10 = round(res/(len(wind_seocho_10_list)),2)
wind_seocho_avg.append(avg_seocho_10)

# %% [markdown]
# ## 11월

# %%
wind_seocho_11 = wind_seocho['M11']
wind_seocho_11_list = wind_seocho_11.tolist()

res = 0
for i in wind_seocho_11_list:
  res+=i

avg_seocho_11 = round(res/(len(wind_seocho_11_list)),2)
wind_seocho_avg.append(avg_seocho_11)

# %% [markdown]
# ## 12월

# %%
wind_seocho_12 = wind_seocho['M12']
wind_seocho_12_list = wind_seocho_12.tolist()

res = 0
for i in wind_seocho_12_list:
  res+=i

avg_seocho_12 = round(res/(len(wind_seocho_12_list)),2)
wind_seocho_avg.append(avg_seocho_12)

# %%
print("서초구 1월~12월 평균 풍속: {}".format(wind_seocho_avg))
# Out:
# 서초구 1월~12월 평균 풍속: [1.47, 1.57, 1.77, 1.71, 1.67, 1.56, 1.55, 1.46, 1.23, 1.23, 1.4, 1.38]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_seocho_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('서초구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 관악구

# %%
wind_gwanak = wind[wind["ADDR_KOR"].str.contains('관악구')]
wind_gwanak
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 13   1.7  1.9  1.9  ...  538973.500  01(풍속평균).shp  POINT (195779.806 538973.500)
# 15   0.0  0.0  0.0  ...  540404.093  01(풍속평균).shp  POINT (198761.581 540404.093)
# 39   1.8  1.3  1.8  ...  543347.016  01(풍속평균).shp  POINT (195419.224 543347.016)
# 64   1.9  1.8  2.3  ...  538973.500  01(풍속평균).shp  POINT (195779.806 538973.500)
# 66   0.0  0.0  0.0  ...  540404.093  01(풍속평균).shp  POINT (198761.581 540404.093)
# 90   0.3  0.2  0.2  ...  543347.016  01(풍속평균).shp  POINT (195419.224 543347.016)
# 125  0.0  0.0  0.0  ...  540404.093  01(풍속평균).shp  POINT (198761.581 540404.093)
# 158  0.0  1.5  1.8  ...  543347.016  01(풍속평균).shp  POINT (195419.224 543347.016)
# 184  0.0  1.6  2.2  ...  538973.500  01(풍속평균).shp  POINT (195779.806 538973.500)
# 186  0.0  0.0  0.0  ...  540404.093  01(풍속평균).shp  POINT (198761.581 540404.093)
# 210  1.5  1.5  1.7  ...  543347.016  01(풍속평균).shp  POINT (195419.224 543347.016)
# ...

# %%
#관악구 월별 평균 리스트
wind_gwanak_avg = []

# %% [markdown]
# ## 1월

# %%
wind_gwanak_01 = wind_gwanak['M01']
wind_gwanak_01_list = wind_gwanak_01.tolist()

res = 0
for i in wind_gwanak_01_list:
  res+=i

avg_gwanak_01 = round(res/(len(wind_gwanak_01_list)),2)
wind_gwanak_avg.append(avg_gwanak_01)

# %% [markdown]
# ## 2월

# %%
wind_gwanak_02 = wind_gwanak['M02']
wind_gwanak_02_list = wind_gwanak_02.tolist()

res = 0
for i in wind_gwanak_02_list:
  res+=i

avg_gwanak_02 = round(res/(len(wind_gwanak_02_list)),2)
wind_gwanak_avg.append(avg_gwanak_02)

# %% [markdown]
# ## 3월

# %%
wind_gwanak_03 = wind_gwanak['M03']
wind_gwanak_03_list = wind_gwanak_03.tolist()

res = 0
for i in wind_gwanak_03_list:
  res+=i

avg_gwanak_03 = round(res/(len(wind_gwanak_03_list)),2)
wind_gwanak_avg.append(avg_gwanak_03)

# %% [markdown]
# ## 4월

# %%
wind_gwanak_04 = wind_gwanak['M04']
wind_gwanak_04_list = wind_gwanak_04.tolist()

res = 0
for i in wind_gwanak_04_list:
  res+=i

avg_gwanak_04 = round(res/(len(wind_gwanak_04_list)),2)
wind_gwanak_avg.append(avg_gwanak_04)

# %% [markdown]
# ## 5월

# %%
wind_gwanak_05 = wind_gwanak['M05']
wind_gwanak_05_list = wind_gwanak_05.tolist()

res = 0
for i in wind_gwanak_05_list:
  res+=i

avg_gwanak_05 = round(res/(len(wind_gwanak_05_list)),2)
wind_gwanak_avg.append(avg_gwanak_05)

# %% [markdown]
# ## 6월

# %%
wind_gwanak_06 = wind_gwanak['M06']
wind_gwanak_06_list = wind_gwanak_06.tolist()

res = 0
for i in wind_gwanak_06_list:
  res+=i

avg_gwanak_06 = round(res/(len(wind_gwanak_06_list)),2)
wind_gwanak_avg.append(avg_gwanak_06)

# %% [markdown]
# ## 7월

# %%
wind_gwanak_07 = wind_gwanak['M07']
wind_gwanak_07_list = wind_gwanak_07.tolist()

res = 0
for i in wind_gwanak_07_list:
  res+=i

avg_gwanak_07 = round(res/(len(wind_gwanak_07_list)),2)
wind_gwanak_avg.append(avg_gwanak_07)

# %% [markdown]
# ## 8월

# %%
wind_gwanak_08 = wind_gwanak['M08']
wind_gwanak_08_list = wind_gwanak_08.tolist()

res = 0
for i in wind_gwanak_08_list:
  res+=i

avg_gwanak_08 = round(res/(len(wind_gwanak_08_list)),2)
wind_gwanak_avg.append(avg_gwanak_08)

# %% [markdown]
# ## 9월

# %%
wind_gwanak_09 = wind_gwanak['M09']
wind_gwanak_09_list = wind_gwanak_09.tolist()

res = 0
for i in wind_gwanak_09_list:
  res+=i

avg_gwanak_09 = round(res/(len(wind_gwanak_09_list)),2)
wind_gwanak_avg.append(avg_gwanak_09)

# %% [markdown]
# ## 10월

# %%
wind_gwanak_10 = wind_gwanak['M10']
wind_gwanak_10_list = wind_gwanak_10.tolist()

res = 0
for i in wind_gwanak_10_list:
  res+=i

avg_gwanak_10 = round(res/(len(wind_gwanak_10_list)),2)
wind_gwanak_avg.append(avg_gwanak_10)

# %% [markdown]
# ## 11월

# %%
wind_gwanak_11 = wind_gwanak['M11']
wind_gwanak_11_list = wind_gwanak_11.tolist()

res = 0
for i in wind_gwanak_11_list:
  res+=i

avg_gwanak_11 = round(res/(len(wind_gwanak_11_list)),2)
wind_gwanak_avg.append(avg_gwanak_11)

# %% [markdown]
# ## 12월

# %%
wind_gwanak_12 = wind_gwanak['M12']
wind_gwanak_12_list = wind_gwanak_12.tolist()

res = 0
for i in wind_gwanak_12_list:
  res+=i

avg_gwanak_12 = round(res/(len(wind_gwanak_12_list)),2)
wind_gwanak_avg.append(avg_gwanak_12)

# %%
print("관악구 1월~12월 평균 풍속: {}".format(wind_gwanak_avg))
# Out:
# 관악구 1월~12월 평균 풍속: [1.1, 1.32, 1.45, 1.45, 1.44, 1.22, 1.26, 1.11, 1.04, 1.13, 1.27, 1.13]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_gwanak_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('관악구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 동작구

# %%
wind_dongjak = wind[wind["ADDR_KOR"].str.contains('동작구')]
wind_dongjak
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 16   0.0  0.0  0.0  ...  544549.170  01(풍속평균).shp  POINT (197922.506 544549.170)
# 38   2.1  2.5  2.7  ...  545743.264  01(풍속평균).shp  POINT (195226.304 545743.264)
# 51   1.6  1.4  2.1  ...  543791.530  01(풍속평균).shp  POINT (193173.535 543791.530)
# 67   0.0  0.0  0.0  ...  544549.170  01(풍속평균).shp  POINT (197922.506 544549.170)
# 89   1.9  2.2  2.6  ...  545743.264  01(풍속평균).shp  POINT (195226.304 545743.264)
# 110  1.6  1.8  2.1  ...  543791.530  01(풍속평균).shp  POINT (193173.535 543791.530)
# 126  0.0  0.0  0.0  ...  544549.170  01(풍속평균).shp  POINT (197922.506 544549.170)
# 157  0.0  1.9  2.4  ...  545743.264  01(풍속평균).shp  POINT (195226.304 545743.264)
# 172  0.0  1.5  2.2  ...  543791.530  01(풍속평균).shp  POINT (193173.535 543791.530)
# 187  0.0  0.0  0.0  ...  544549.170  01(풍속평균).shp  POINT (197922.506 544549.170)
# 209  2.1  2.1  2.6  ...  545743.264  01(풍속평균).shp  POINT (195226.304 545743.264)
# ...

# %%
#동작구 월별 평균 리스트
wind_dongjak_avg = []

# %% [markdown]
# ## 1월

# %%
wind_dongjak_01 = wind_dongjak['M01']
wind_dongjak_01_list = wind_dongjak_01.tolist()

res = 0
for i in wind_dongjak_01_list:
  res+=i

avg_dongjak_01 = round(res/(len(wind_dongjak_01_list)),2)
wind_dongjak_avg.append(avg_dongjak_01)

# %% [markdown]
# ## 2월

# %%
wind_dongjak_02 = wind_dongjak['M02']
wind_dongjak_02_list = wind_dongjak_02.tolist()

res = 0
for i in wind_dongjak_02_list:
  res+=i

avg_dongjak_02 = round(res/(len(wind_dongjak_02_list)),2)
wind_dongjak_avg.append(avg_dongjak_02)

# %% [markdown]
# ## 3월

# %%
wind_dongjak_03 = wind_dongjak['M03']
wind_dongjak_03_list = wind_dongjak_03.tolist()

res = 0
for i in wind_dongjak_03_list:
  res+=i

avg_dongjak_03 = round(res/(len(wind_dongjak_03_list)),2)
wind_dongjak_avg.append(avg_dongjak_03)

# %% [markdown]
# ## 4월

# %%
wind_dongjak_04 = wind_dongjak['M04']
wind_dongjak_04_list = wind_dongjak_04.tolist()

res = 0
for i in wind_dongjak_04_list:
  res+=i

avg_dongjak_04 = round(res/(len(wind_dongjak_04_list)),2)
wind_dongjak_avg.append(avg_dongjak_04)

# %% [markdown]
# ## 5월

# %%
wind_dongjak_05 = wind_dongjak['M05']
wind_dongjak_05_list = wind_dongjak_05.tolist()

res = 0
for i in wind_dongjak_05_list:
  res+=i

avg_dongjak_05 = round(res/(len(wind_dongjak_05_list)),2)
wind_dongjak_avg.append(avg_dongjak_05)

# %% [markdown]
# ## 6월

# %%
wind_dongjak_06 = wind_dongjak['M06']
wind_dongjak_06_list = wind_dongjak_06.tolist()

res = 0
for i in wind_dongjak_06_list:
  res+=i

avg_dongjak_06 = round(res/(len(wind_dongjak_06_list)),2)
wind_dongjak_avg.append(avg_dongjak_06)

# %% [markdown]
# ## 7월

# %%
wind_dongjak_07 = wind_dongjak['M07']
wind_dongjak_07_list = wind_dongjak_07.tolist()

res = 0
for i in wind_dongjak_07_list:
  res+=i

avg_dongjak_07 = round(res/(len(wind_dongjak_07_list)),2)
wind_dongjak_avg.append(avg_dongjak_07)

# %% [markdown]
# ## 8월

# %%
wind_dongjak_08 = wind_dongjak['M08']
wind_dongjak_08_list = wind_dongjak_08.tolist()

res = 0
for i in wind_dongjak_08_list:
  res+=i

avg_dongjak_08 = round(res/(len(wind_dongjak_08_list)),2)
wind_dongjak_avg.append(avg_dongjak_08)

# %% [markdown]
# ## 9월

# %%
wind_dongjak_09 = wind_dongjak['M09']
wind_dongjak_09_list = wind_dongjak_09.tolist()

res = 0
for i in wind_dongjak_09_list:
  res+=i

avg_dongjak_09 = round(res/(len(wind_dongjak_09_list)),2)
wind_dongjak_avg.append(avg_dongjak_09)

# %% [markdown]
# ## 10월

# %%
wind_dongjak_10 = wind_dongjak['M10']
wind_dongjak_10_list = wind_dongjak_10.tolist()

res = 0
for i in wind_dongjak_10_list:
  res+=i

avg_dongjak_10 = round(res/(len(wind_dongjak_10_list)),2)
wind_dongjak_avg.append(avg_dongjak_10)

# %% [markdown]
# ## 11월

# %%
wind_dongjak_11 = wind_dongjak['M11']
wind_dongjak_11_list = wind_dongjak_11.tolist()

res = 0
for i in wind_dongjak_11_list:
  res+=i

avg_dongjak_11 = round(res/(len(wind_dongjak_11_list)),2)
wind_dongjak_avg.append(avg_dongjak_11)

# %% [markdown]
# ## 12월

# %%
wind_dongjak_12 = wind_dongjak['M12']
wind_dongjak_12_list = wind_dongjak_12.tolist()

res = 0
for i in wind_dongjak_12_list:
  res+=i

avg_dongjak_12 = round(res/(len(wind_dongjak_12_list)),2)
wind_dongjak_avg.append(avg_dongjak_12)

# %%
print("동작구 1월~12월 평균 풍속: {}".format(wind_dongjak_avg))
# Out:
# 동작구 1월~12월 평균 풍속: [1.2, 1.43, 1.63, 1.58, 1.63, 1.44, 1.5, 1.39, 1.25, 1.24, 1.4, 1.24]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_dongjak_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('동작구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 영등포구

# %%
wind_ydp = wind[wind["ADDR_KOR"].str.contains('영등포구')]
wind_ydp
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 14   1.5  1.6  2.1  ...  547421.601  01(풍속평균).shp  POINT (191868.430 547421.601)
# 23   2.8  2.2  3.4  ...  548929.200  01(풍속평균).shp  POINT (190270.688 548929.200)
# 59   1.0  1.1  1.4  ...  546875.569  01(풍속평균).shp  POINT (194643.582 546875.569)
# 65   1.4  1.3  2.0  ...  547421.601  01(풍속평균).shp  POINT (191868.430 547421.601)
# 74   2.7  3.0  3.1  ...  548929.200  01(풍속평균).shp  POINT (190270.688 548929.200)
# 102  1.1  1.3  1.8  ...  546875.569  01(풍속평균).shp  POINT (194643.582 546875.569)
# 118  0.8  1.0  1.4  ...  546875.569  01(풍속평균).shp  POINT (194643.582 546875.569)
# 124  1.3  1.5  1.9  ...  547421.601  01(풍속평균).shp  POINT (191868.430 547421.601)
# 133  2.5  2.9  3.0  ...  548929.200  01(풍속평균).shp  POINT (190270.688 548929.200)
# 142  2.5  2.8  3.2  ...  548929.200  01(풍속평균).shp  POINT (190270.688 548929.200)
# 179  0.0  1.4  1.9  ...  546875.569  01(풍속평균).shp  POINT (194643.582 546875.569)
# ...

# %%
#영등포구 월별 평균 리스트
wind_ydp_avg = []

# %% [markdown]
# ## 1월

# %%
wind_ydp_01 = wind_ydp['M01']
wind_ydp_01_list = wind_ydp_01.tolist()

res = 0
for i in wind_ydp_01_list:
  res+=i

avg_ydp_01 = round(res/(len(wind_ydp_01_list)),2)
wind_ydp_avg.append(avg_ydp_01)

# %% [markdown]
# ## 2월

# %%
wind_ydp_02 = wind_ydp['M02']
wind_ydp_02_list = wind_ydp_02.tolist()

res = 0
for i in wind_ydp_02_list:
  res+=i

avg_ydp_02 = round(res/(len(wind_ydp_02_list)),2)
wind_ydp_avg.append(avg_ydp_02)

# %% [markdown]
# ## 3월

# %%
wind_ydp_03 = wind_ydp['M03']
wind_ydp_03_list = wind_ydp_03.tolist()

res = 0
for i in wind_ydp_03_list:
  res+=i

avg_ydp_03 = round(res/(len(wind_ydp_03_list)),2)
wind_ydp_avg.append(avg_ydp_03)

# %% [markdown]
# ## 4월

# %%
wind_ydp_04 = wind_ydp['M04']
wind_ydp_04_list = wind_ydp_04.tolist()

res = 0
for i in wind_ydp_04_list:
  res+=i

avg_ydp_04 = round(res/(len(wind_ydp_04_list)),2)
wind_ydp_avg.append(avg_ydp_04)

# %% [markdown]
# ## 5월

# %%
wind_ydp_05 = wind_ydp['M05']
wind_ydp_05_list = wind_ydp_05.tolist()

res = 0
for i in wind_ydp_05_list:
  res+=i

avg_ydp_05 = round(res/(len(wind_ydp_05_list)),2)
wind_ydp_avg.append(avg_ydp_05)

# %% [markdown]
# ## 6월

# %%
wind_ydp_06 = wind_ydp['M06']
wind_ydp_06_list = wind_ydp_06.tolist()

res = 0
for i in wind_ydp_06_list:
  res+=i

avg_ydp_06 = round(res/(len(wind_ydp_06_list)),2)
wind_ydp_avg.append(avg_ydp_06)

# %% [markdown]
# ## 7월

# %%
wind_ydp_07 = wind_ydp['M07']
wind_ydp_07_list = wind_ydp_07.tolist()

res = 0
for i in wind_ydp_07_list:
  res+=i

avg_ydp_07 = round(res/(len(wind_ydp_07_list)),2)
wind_ydp_avg.append(avg_ydp_07)

# %% [markdown]
# ## 8월

# %%
wind_ydp_08 = wind_ydp['M08']
wind_ydp_08_list = wind_ydp_08.tolist()

res = 0
for i in wind_ydp_08_list:
  res+=i

avg_ydp_08 = round(res/(len(wind_ydp_08_list)),2)
wind_ydp_avg.append(avg_ydp_08)

# %% [markdown]
# ## 9월

# %%
wind_ydp_09 = wind_ydp['M09']
wind_ydp_09_list = wind_ydp_09.tolist()

res = 0
for i in wind_ydp_09_list:
  res+=i

avg_ydp_09 = round(res/(len(wind_ydp_09_list)),2)
wind_ydp_avg.append(avg_ydp_09)

# %% [markdown]
# ## 10월

# %%
wind_ydp_10 = wind_ydp['M10']
wind_ydp_10_list = wind_ydp_10.tolist()

res = 0
for i in wind_ydp_10_list:
  res+=i

avg_ydp_10 = round(res/(len(wind_ydp_10_list)),2)
wind_ydp_avg.append(avg_ydp_10)

# %% [markdown]
# ## 11월

# %%
wind_ydp_11 = wind_ydp['M11']
wind_ydp_11_list = wind_ydp_11.tolist()

res = 0
for i in wind_ydp_11_list:
  res+=i

avg_ydp_11 = round(res/(len(wind_ydp_11_list)),2)
wind_ydp_avg.append(avg_ydp_11)

# %% [markdown]
# ## 12월

# %%
wind_ydp_12 = wind_ydp['M12']
wind_ydp_12_list = wind_ydp_12.tolist()

res = 0
for i in wind_ydp_12_list:
  res+=i

avg_ydp_12 = round(res/(len(wind_ydp_12_list)),2)
wind_ydp_avg.append(avg_ydp_12)

# %%
print("영등포구 1월~12월 평균 풍속: {}".format(wind_ydp_avg))
# Out:
# 영등포구 1월~12월 평균 풍속: [1.83, 2.02, 2.24, 2.14, 2.11, 1.94, 2.02, 1.97, 1.83, 1.83, 2.01, 1.81]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_ydp_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('영듣포구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 금천구

# %%
wind_gc = wind[wind["ADDR_KOR"].str.contains('금천구')]
wind_gc
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 1    1.6  1.9  2.3  ...  539796.939  01(풍속평균).shp  POINT (192586.637 539796.939)
# 6    1.9  2.2  2.6  ...  540742.881  01(풍속평균).shp  POINT (191127.725 540742.881)
# 26   0.4  2.4  2.6  ...  540742.881  01(풍속평균).shp  POINT (191127.725 540742.881)
# 58   1.8  1.6  2.3  ...  539796.939  01(풍속평균).shp  POINT (192586.637 539796.939)
# 107  2.0  2.2  2.6  ...  540742.881  01(풍속평균).shp  POINT (191127.725 540742.881)
# 117  1.7  1.9  2.2  ...  539796.939  01(풍속평균).shp  POINT (192586.637 539796.939)
# 146  2.0  2.1  2.6  ...  540742.881  01(풍속평균).shp  POINT (191127.725 540742.881)
# 178  0.0  0.8  1.3  ...  539796.939  01(풍속평균).shp  POINT (192586.637 539796.939)
# 246  1.8  2.0  2.2  ...  540742.881  01(풍속평균).shp  POINT (191127.725 540742.881)
# 279  1.6  1.7  1.9  ...  539796.939  01(풍속평균).shp  POINT (192586.637 539796.939)
# 300  2.0  2.1  2.2  ...  540742.881  01(풍속평균).shp  POINT (191127.725 540742.881)
# ...

# %%
#금천구 월별 평균 리스트
wind_gc_avg = []

# %% [markdown]
# ## 1월

# %%
wind_gc_01 = wind_gc['M01']
wind_gc_01_list = wind_gc_01.tolist()

res = 0
for i in wind_gc_01_list:
  res+=i

avg_gc_01 = round(res/(len(wind_gc_01_list)),2)
wind_gc_avg.append(avg_gc_01)

# %% [markdown]
# ## 2월

# %%
wind_gc_02 = wind_gc['M02']
wind_gc_02_list = wind_gc_02.tolist()

res = 0
for i in wind_gc_02_list:
  res+=i

avg_gc_02 = round(res/(len(wind_gc_02_list)),2)
wind_gc_avg.append(avg_gc_02)

# %% [markdown]
# ## 3월

# %%
wind_gc_03 = wind_gc['M03']
wind_gc_03_list = wind_gc_03.tolist()

res = 0
for i in wind_gc_03_list:
  res+=i

avg_gc_03 = round(res/(len(wind_gc_03_list)),2)
wind_gc_avg.append(avg_gc_03)

# %% [markdown]
# ## 4월

# %%
wind_gc_04 = wind_gc['M04']
wind_gc_04_list = wind_gc_04.tolist()

res = 0
for i in wind_gc_04_list:
  res+=i

avg_gc_04 = round(res/(len(wind_gc_04_list)),2)
wind_gc_avg.append(avg_gc_04)

# %% [markdown]
# ## 5월

# %%
wind_gc_05 = wind_gc['M05']
wind_gc_05_list = wind_gc_05.tolist()

res = 0
for i in wind_gc_05_list:
  res+=i

avg_gc_05 = round(res/(len(wind_gc_05_list)),2)
wind_gc_avg.append(avg_gc_05)

# %% [markdown]
# ## 6월

# %%
wind_gc_06 = wind_gc['M06']
wind_gc_06_list = wind_gc_06.tolist()

res = 0
for i in wind_gc_06_list:
  res+=i

avg_gc_06 = round(res/(len(wind_gc_06_list)),2)
wind_gc_avg.append(avg_gc_06)

# %% [markdown]
# ## 7월

# %%
wind_gc_07 = wind_gc['M07']
wind_gc_07_list = wind_gc_07.tolist()

res = 0
for i in wind_gc_07_list:
  res+=i

avg_gc_07 = round(res/(len(wind_gc_07_list)),2)
wind_gc_avg.append(avg_gc_07)

# %% [markdown]
# ## 8월

# %%
wind_gc_08 = wind_gc['M08']
wind_gc_08_list = wind_gc_08.tolist()

res = 0
for i in wind_gc_08_list:
  res+=i

avg_gc_08 = round(res/(len(wind_gc_08_list)),2)
wind_gc_avg.append(avg_gc_08)

# %% [markdown]
# ## 9월

# %%
wind_gc_09 = wind_gc['M09']
wind_gc_09_list = wind_gc_09.tolist()

res = 0
for i in wind_gc_09_list:
  res+=i

avg_gc_09 = round(res/(len(wind_gc_09_list)),2)
wind_gc_avg.append(avg_gc_09)

# %% [markdown]
# ## 10월

# %%
wind_gc_10 = wind_gc['M10']
wind_gc_10_list = wind_gc_10.tolist()

res = 0
for i in wind_gc_10_list:
  res+=i

avg_gc_10 = round(res/(len(wind_gc_10_list)),2)
wind_gc_avg.append(avg_gc_10)

# %% [markdown]
# ## 11월

# %%
wind_gc_11 = wind_gc['M11']
wind_gc_11_list = wind_gc_11.tolist()

res = 0
for i in wind_gc_11_list:
  res+=i

avg_gc_11 = round(res/(len(wind_gc_11_list)),2)
wind_gc_avg.append(avg_gc_11)

# %% [markdown]
# ## 12월

# %%
wind_gc_12 = wind_gc['M12']
wind_gc_12_list = wind_gc_12.tolist()

res = 0
for i in wind_gc_12_list:
  res+=i

avg_gc_12 = round(res/(len(wind_gc_12_list)),2)
wind_gc_avg.append(avg_gc_12)

# %%
print("금천구 1월~12월 평균 풍속: {}".format(wind_gc_avg))
# Out:
# 금천구 1월~12월 평균 풍속: [1.56, 1.84, 2.12, 2.17, 2.2, 1.97, 2.22, 2.08, 1.8, 1.73, 1.84, 1.54]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_gc_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('금천구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 구로구

# %%
wind_gr = wind[wind["ADDR_KOR"].str.contains('구로구')]
wind_gr
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 5    0.0  1.8  2.5  ...  542669.837  01(풍속평균).shp  POINT (185257.710 542669.837)
# 11   0.7  1.2  2.0  ...  542669.837  01(풍속평균).shp  POINT (185257.710 542669.837)
# 22   1.9  2.7  2.9  ...  543519.869  01(풍속평균).shp  POINT (189663.309 543519.869)
# 73   2.0  2.3  2.9  ...  543519.869  01(풍속평균).shp  POINT (189663.309 543519.869)
# 106  1.7  1.8  2.5  ...  542669.837  01(풍속평균).shp  POINT (185257.710 542669.837)
# 122  2.0  2.2  2.8  ...  542669.837  01(풍속평균).shp  POINT (185257.710 542669.837)
# 132  2.1  2.2  2.4  ...  543519.869  01(풍속평균).shp  POINT (189663.309 543519.869)
# 141  2.3  2.4  2.9  ...  543519.869  01(풍속평균).shp  POINT (189663.309 543519.869)
# 193  2.3  2.4  3.0  ...  543519.869  01(풍속평균).shp  POINT (189663.309 543519.869)
# 231  1.4  2.1  2.4  ...  542669.837  01(풍속평균).shp  POINT (185257.710 542669.837)
# 284  2.0  2.0  2.1  ...  542669.837  01(풍속평균).shp  POINT (185257.710 542669.837)
# ...

# %%
#구로구 월별 평균 리스트
wind_gr_avg = []

# %% [markdown]
# ## 1월

# %%
wind_gr_01 = wind_gr['M01']
wind_gr_01_list = wind_gr_01.tolist()

res = 0
for i in wind_gr_01_list:
  res+=i

avg_gr_01 = round(res/(len(wind_gr_01_list)),2)
wind_gr_avg.append(avg_gr_01)

# %% [markdown]
# ## 2월

# %%
wind_gr_02 = wind_gr['M02']
wind_gr_02_list = wind_gr_02.tolist()

res = 0
for i in wind_gr_02_list:
  res+=i

avg_gr_02 = round(res/(len(wind_gr_02_list)),2)
wind_gr_avg.append(avg_gr_02)

# %% [markdown]
# ## 3월

# %%
wind_gr_03 = wind_gr['M03']
wind_gr_03_list = wind_gr_03.tolist()

res = 0
for i in wind_gr_03_list:
  res+=i

avg_gr_03 = round(res/(len(wind_gr_03_list)),2)
wind_gr_avg.append(avg_gr_03)

# %% [markdown]
# ## 4월

# %%
wind_gr_04 = wind_gr['M04']
wind_gr_04_list = wind_gr_04.tolist()

res = 0
for i in wind_gr_04_list:
  res+=i

avg_gr_04 = round(res/(len(wind_gr_04_list)),2)
wind_gr_avg.append(avg_gr_04)

# %% [markdown]
# ## 5월

# %%
wind_gr_05 = wind_gr['M05']
wind_gr_05_list = wind_gr_05.tolist()

res = 0
for i in wind_gr_05_list:
  res+=i

avg_gr_05 = round(res/(len(wind_gr_05_list)),2)
wind_gr_avg.append(avg_gr_05)

# %% [markdown]
# ## 6월

# %%
wind_gr_06 = wind_gr['M06']
wind_gr_06_list = wind_gr_06.tolist()

res = 0
for i in wind_gr_06_list:
  res+=i

avg_gr_06 = round(res/(len(wind_gr_06_list)),2)
wind_gr_avg.append(avg_gr_06)

# %% [markdown]
# ## 7월

# %%
wind_gr_07 = wind_gr['M07']
wind_gr_07_list = wind_gr_07.tolist()

res = 0
for i in wind_gr_07_list:
  res+=i

avg_gr_07 = round(res/(len(wind_gr_07_list)),2)
wind_gr_avg.append(avg_gr_07)

# %% [markdown]
# ## 8월

# %%
wind_gr_08 = wind_gr['M08']
wind_gr_08_list = wind_gr_08.tolist()

res = 0
for i in wind_gr_08_list:
  res+=i

avg_gr_08 = round(res/(len(wind_gr_08_list)),2)
wind_gr_avg.append(avg_gr_08)

# %% [markdown]
# ## 9월

# %%
wind_gr_09 = wind_gr['M09']
wind_gr_09_list = wind_gr_09.tolist()

res = 0
for i in wind_gr_09_list:
  res+=i

avg_gr_09 = round(res/(len(wind_gr_09_list)),2)
wind_gr_avg.append(avg_gr_09)

# %% [markdown]
# ## 10월

# %%
wind_gr_10 = wind_gr['M10']
wind_gr_10_list = wind_gr_10.tolist()

res = 0
for i in wind_gr_10_list:
  res+=i

avg_gr_10 = round(res/(len(wind_gr_10_list)),2)
wind_gr_avg.append(avg_gr_10)

# %% [markdown]
# ## 11월

# %%
wind_gr_11 = wind_gr['M10']
wind_gr_11_list = wind_gr_11.tolist()

res = 0
for i in wind_gr_11_list:
  res+=i

avg_gr_11 = round(res/(len(wind_gr_11_list)),2)
wind_gr_avg.append(avg_gr_11)

# %% [markdown]
# ## 12월

# %%
wind_gr_12 = wind_gr['M12']
wind_gr_12_list = wind_gr_12.tolist()

res = 0
for i in wind_gr_12_list:
  res+=i

avg_gr_12 = round(res/(len(wind_gr_12_list)),2)
wind_gr_avg.append(avg_gr_12)

# %%
print("구로구 1월~12월 평균 풍속: {}".format(wind_gr_avg))
# Out:
# 구로구 1월~12월 평균 풍속: [1.72, 2.11, 2.42, 2.46, 2.35, 2.17, 2.34, 2.26, 1.95, 1.89, 1.89, 1.74]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_gr_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('구로구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 강서구

# %%
wind_gangseo = wind[wind["ADDR_KOR"].str.contains('강서구')]
wind_gangseo
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 40   1.5  2.6  2.1  ...  550772.700  01(풍속평균).shp  POINT (188532.380 550772.700)
# 46   1.3  1.4  1.9  ...  550069.424  01(풍속평균).shp  POINT (186746.370 550069.424)
# 92   1.5  1.7  2.5  ...  550772.700  01(풍속평균).shp  POINT (188532.380 550772.700)
# 98   1.3  1.5  2.0  ...  550069.424  01(풍속평균).shp  POINT (186746.370 550069.424)
# 160  0.0  1.6  2.0  ...  550772.700  01(풍속평균).shp  POINT (188532.380 550772.700)
# 166  0.0  1.3  2.0  ...  550069.424  01(풍속평균).shp  POINT (186746.370 550069.424)
# 212  1.6  1.7  2.5  ...  550772.700  01(풍속평균).shp  POINT (188532.380 550772.700)
# 217  1.4  1.5  2.0  ...  550069.424  01(풍속평균).shp  POINT (186746.370 550069.424)
# 260  1.5  1.8  1.8  ...  550772.700  01(풍속평균).shp  POINT (188532.380 550772.700)
# 266  1.4  1.8  1.7  ...  550069.424  01(풍속평균).shp  POINT (186746.370 550069.424)
# 318  1.6  1.9  1.7  ...  550772.700  01(풍속평균).shp  POINT (188532.380 550772.700)
# ...

# %%
#강서구 월별 평균 리스트
wind_gangseo_avg = []

# %% [markdown]
# ## 1월

# %%
wind_gangseo_01 = wind_gangseo['M01']
wind_gangseo_01_list = wind_gangseo_01.tolist()

res = 0
for i in wind_gangseo_01_list:
  res+=i

avg_gangseo_01 = round(res/(len(wind_gangseo_01_list)),2)
wind_gangseo_avg.append(avg_gangseo_01)

# %% [markdown]
# ## 2월

# %%
wind_gangseo_02 = wind_gangseo['M02']
wind_gangseo_02_list = wind_gangseo_02.tolist()

res = 0
for i in wind_gangseo_02_list:
  res+=i

avg_gangseo_02 = round(res/(len(wind_gangseo_02_list)),2)
wind_gangseo_avg.append(avg_gangseo_02)

# %% [markdown]
# ## 3월

# %%
wind_gangseo_03 = wind_gangseo['M03']
wind_gangseo_03_list = wind_gangseo_03.tolist()

res = 0
for i in wind_gangseo_03_list:
  res+=i

avg_gangseo_03 = round(res/(len(wind_gangseo_03_list)),2)
wind_gangseo_avg.append(avg_gangseo_03)

# %% [markdown]
# ## 4월

# %%
wind_gangseo_04 = wind_gangseo['M04']
wind_gangseo_04_list = wind_gangseo_04.tolist()

res = 0
for i in wind_gangseo_04_list:
  res+=i

avg_gangseo_04 = round(res/(len(wind_gangseo_04_list)),2)
wind_gangseo_avg.append(avg_gangseo_04)

# %% [markdown]
# ## 5월

# %%
wind_gangseo_05 = wind_gangseo['M05']
wind_gangseo_05_list = wind_gangseo_05.tolist()

res = 0
for i in wind_gangseo_05_list:
  res+=i

avg_gangseo_05 = round(res/(len(wind_gangseo_05_list)),2)
wind_gangseo_avg.append(avg_gangseo_05)

# %% [markdown]
# ## 6월

# %%
wind_gangseo_06 = wind_gangseo['M06']
wind_gangseo_06_list = wind_gangseo_06.tolist()

res = 0
for i in wind_gangseo_06_list:
  res+=i

avg_gangseo_06 = round(res/(len(wind_gangseo_06_list)),2)
wind_gangseo_avg.append(avg_gangseo_06)

# %% [markdown]
# ## 7월

# %%
wind_gangseo_07 = wind_gangseo['M07']
wind_gangseo_07_list = wind_gangseo_07.tolist()

res = 0
for i in wind_gangseo_07_list:
  res+=i

avg_gangseo_07 = round(res/(len(wind_gangseo_07_list)),2)
wind_gangseo_avg.append(avg_gangseo_07)

# %% [markdown]
# ## 8월

# %%
wind_gangseo_08 = wind_gangseo['M08']
wind_gangseo_08_list = wind_gangseo_08.tolist()

res = 0
for i in wind_gangseo_08_list:
  res+=i

avg_gangseo_08 = round(res/(len(wind_gangseo_08_list)),2)
wind_gangseo_avg.append(avg_gangseo_08)

# %% [markdown]
# ## 9월

# %%
wind_gangseo_09 = wind_gangseo['M09']
wind_gangseo_09_list = wind_gangseo_09.tolist()

res = 0
for i in wind_gangseo_09_list:
  res+=i

avg_gangseo_09 = round(res/(len(wind_gangseo_09_list)),2)
wind_gangseo_avg.append(avg_gangseo_09)

# %% [markdown]
# ## 10월

# %%
wind_gangseo_10 = wind_gangseo['M10']
wind_gangseo_10_list = wind_gangseo_10.tolist()

res = 0
for i in wind_gangseo_10_list:
  res+=i

avg_gangseo_10 = round(res/(len(wind_gangseo_10_list)),2)
wind_gangseo_avg.append(avg_gangseo_10)

# %% [markdown]
# ## 11월

# %%
wind_gangseo_11 = wind_gangseo['M11']
wind_gangseo_11_list = wind_gangseo_11.tolist()

res = 0
for i in wind_gangseo_11_list:
  res+=i

avg_gangseo_11 = round(res/(len(wind_gangseo_11_list)),2)
wind_gangseo_avg.append(avg_gangseo_11)

# %% [markdown]
# ## 12월

# %%
wind_gangseo_12 = wind_gangseo['M12']
wind_gangseo_12_list = wind_gangseo_12.tolist()

res = 0
for i in wind_gangseo_12_list:
  res+=i

avg_gangseo_12 = round(res/(len(wind_gangseo_12_list)),2)
wind_gangseo_avg.append(avg_gangseo_12)

# %%
print("강서구 1월~12월 평균 풍속: {}".format(wind_gangseo_avg))
# Out:
# 강서구 1월~12월 평균 풍속: [1.29, 1.69, 1.89, 2.02, 1.87, 1.74, 1.8, 1.81, 1.59, 1.45, 1.67, 1.41]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_gangseo_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.ylim([0,2.5])
plt.title('강서구 2009~2017 월평균 풍속')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 양천구

# %%
wind_yc = wind[wind["ADDR_KOR"].str.contains('양천구')]
wind_yc
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 27   1.8  2.0  2.0  ...  547767.272  01(풍속평균).shp  POINT (189323.902 547767.272)
# 78   1.7  1.8  2.0  ...  547767.272  01(풍속평균).shp  POINT (189323.902 547767.272)
# 99   1.4  1.3  1.8  ...  547180.014  01(풍속평균).shp  POINT (189331.986 547180.014)
# 105  1.7  1.4  2.0  ...  547180.014  01(풍속평균).shp  POINT (189331.986 547180.014)
# 147  0.0  1.7  2.0  ...  547767.272  01(풍속평균).shp  POINT (189323.902 547767.272)
# 167  0.0  0.6  1.0  ...  547180.014  01(풍속평균).shp  POINT (189331.986 547180.014)
# 198  1.7  1.7  2.1  ...  547767.272  01(풍속평균).shp  POINT (189323.902 547767.272)
# 218  1.4  1.5  1.8  ...  547180.014  01(풍속평균).shp  POINT (189331.986 547180.014)
# 247  1.6  1.5  1.5  ...  547767.272  01(풍속평균).shp  POINT (189323.902 547767.272)
# 267  1.4  1.5  1.6  ...  547180.014  01(풍속평균).shp  POINT (189331.986 547180.014)
# 301  1.6  1.6  1.6  ...  547767.272  01(풍속평균).shp  POINT (189323.902 547767.272)
# ...

# %%
#양천구 월별 평균 리스트
wind_yc_avg = []

# %% [markdown]
# ## 1월

# %%
wind_yc_01 = wind_yc['M01']
wind_yc_01_list = wind_yc_01.tolist()

res = 0
for i in wind_yc_01_list:
  res+=i

avg_yc_01 = round(res/(len(wind_yc_01_list)),2)
wind_yc_avg.append(avg_yc_01)

# %% [markdown]
# ## 2월

# %%
wind_yc_02 = wind_yc['M02']
wind_yc_02_list = wind_yc_02.tolist()

res = 0
for i in wind_yc_02_list:
  res+=i

avg_yc_02 = round(res/(len(wind_yc_02_list)),2)
wind_yc_avg.append(avg_yc_02)

# %% [markdown]
# ## 3월

# %%
wind_yc_03 = wind_yc['M03']
wind_yc_03_list = wind_yc_03.tolist()

res = 0
for i in wind_yc_03_list:
  res+=i

avg_yc_03 = round(res/(len(wind_yc_03_list)),2)
wind_yc_avg.append(avg_yc_03)

# %% [markdown]
# ## 4월

# %%
wind_yc_04 = wind_yc['M04']
wind_yc_04_list = wind_yc_04.tolist()

res = 0
for i in wind_yc_04_list:
  res+=i

avg_yc_04 = round(res/(len(wind_yc_04_list)),2)
wind_yc_avg.append(avg_yc_04)

# %% [markdown]
# ## 5월

# %%
wind_yc_05 = wind_yc['M05']
wind_yc_05_list = wind_yc_05.tolist()

res = 0
for i in wind_yc_05_list:
  res+=i

avg_yc_05 = round(res/(len(wind_yc_05_list)),2)
wind_yc_avg.append(avg_yc_05)

# %% [markdown]
# ## 6월

# %%
wind_yc_06 = wind_yc['M06']
wind_yc_06_list = wind_yc_06.tolist()

res = 0
for i in wind_yc_06_list:
  res+=i

avg_yc_06 = round(res/(len(wind_yc_06_list)),2)
wind_yc_avg.append(avg_yc_06)

# %% [markdown]
# ## 7월

# %%
wind_yc_07 = wind_yc['M07']
wind_yc_07_list = wind_yc_07.tolist()

res = 0
for i in wind_yc_07_list:
  res+=i

avg_yc_07 = round(res/(len(wind_yc_07_list)),2)
wind_yc_avg.append(avg_yc_07)

# %% [markdown]
# ## 8월

# %%
wind_yc_08 = wind_yc['M08']
wind_yc_08_list = wind_yc_08.tolist()

res = 0
for i in wind_yc_08_list:
  res+=i

avg_yc_08 = round(res/(len(wind_yc_08_list)),2)
wind_yc_avg.append(avg_yc_08)

# %% [markdown]
# ## 9월

# %%
wind_yc_09 = wind_yc['M09']
wind_yc_09_list = wind_yc_09.tolist()

res = 0
for i in wind_yc_09_list:
  res+=i

avg_yc_09 = round(res/(len(wind_yc_09_list)),2)
wind_yc_avg.append(avg_yc_09)

# %% [markdown]
# ## 10월

# %%
wind_yc_10 = wind_yc['M10']
wind_yc_10_list = wind_yc_10.tolist()

res = 0
for i in wind_yc_10_list:
  res+=i

avg_yc_10 = round(res/(len(wind_yc_10_list)),2)
wind_yc_avg.append(avg_yc_10)

# %% [markdown]
# ## 11월

# %%
wind_yc_11 = wind_yc['M11']
wind_yc_11_list = wind_yc_11.tolist()

res = 0
for i in wind_yc_11_list:
  res+=i

avg_yc_11 = round(res/(len(wind_yc_11_list)),2)
wind_yc_avg.append(avg_yc_11)

# %% [markdown]
# ## 12월

# %%
wind_yc_12 = wind_yc['M12']
wind_yc_12_list = wind_yc_12.tolist()

res = 0
for i in wind_yc_12_list:
  res+=i

avg_yc_12 = round(res/(len(wind_yc_12_list)),2)
wind_yc_avg.append(avg_yc_12)

# %%
print("양천구 1월~12월 평균 풍속: {}".format(wind_yc_avg))
# Out:
# 양천구 1월~12월 평균 풍속: [1.33, 1.51, 1.71, 1.64, 1.59, 1.48, 1.63, 1.55, 1.38, 1.32, 1.47, 1.39]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_yc_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('양천구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 마포구

# %%
wind_mapo = wind[wind["ADDR_KOR"].str.contains('마포구')]
wind_mapo
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 4    0.0  1.9  2.6  ...  549294.842  01(풍속평균).shp  POINT (194185.402 549294.842)
# 21   1.4  1.6  1.6  ...  552697.015  01(풍속평균).shp  POINT (191229.289 552697.015)
# 52   2.0  1.8  2.8  ...  549294.842  01(풍속평균).shp  POINT (194185.402 549294.842)
# 72   1.3  1.5  1.7  ...  552697.015  01(풍속평균).shp  POINT (191229.289 552697.015)
# 111  2.7  3.1  3.3  ...  549294.842  01(풍속평균).shp  POINT (194185.402 549294.842)
# 131  1.3  1.5  1.5  ...  552697.015  01(풍속평균).shp  POINT (191229.289 552697.015)
# 140  1.4  1.6  1.9  ...  552697.015  01(풍속평균).shp  POINT (191229.289 552697.015)
# 192  1.4  1.5  2.0  ...  552697.015  01(풍속평균).shp  POINT (191229.289 552697.015)
# 224  1.9  2.1  2.8  ...  549294.842  01(풍속평균).shp  POINT (194185.402 549294.842)
# 241  1.1  1.2  1.3  ...  552697.015  01(풍속평균).shp  POINT (191229.289 552697.015)
# 273  2.8  2.9  2.8  ...  549294.842  01(풍속평균).shp  POINT (194185.402 549294.842)
# ...

# %%
#마포구 월별 평균 리스트
wind_mapo_avg = []

# %% [markdown]
# ## 1월

# %%
wind_mapo_01 = wind_mapo['M01']
wind_mapo_01_list = wind_mapo_01.tolist()

res = 0
for i in wind_mapo_01_list:
  res+=i

avg_mapo_01 = round(res/(len(wind_mapo_01_list)),2)
wind_mapo_avg.append(avg_mapo_01)

# %% [markdown]
# ## 2월

# %%
wind_mapo_02 = wind_mapo['M02']
wind_mapo_02_list = wind_mapo_02.tolist()

res = 0
for i in wind_mapo_02_list:
  res+=i

avg_mapo_02 = round(res/(len(wind_mapo_02_list)),2)
wind_mapo_avg.append(avg_mapo_02)

# %% [markdown]
# ## 3월

# %%
wind_mapo_03 = wind_mapo['M03']
wind_mapo_03_list = wind_mapo_03.tolist()

res = 0
for i in wind_mapo_03_list:
  res+=i

avg_mapo_03 = round(res/(len(wind_mapo_03_list)),2)
wind_mapo_avg.append(avg_mapo_03)

# %% [markdown]
# ## 4월

# %%
wind_mapo_04 = wind_mapo['M04']
wind_mapo_04_list = wind_mapo_04.tolist()

res = 0
for i in wind_mapo_04_list:
  res+=i

avg_mapo_04 = round(res/(len(wind_mapo_04_list)),2)
wind_mapo_avg.append(avg_mapo_04)

# %% [markdown]
# ## 5월

# %%
wind_mapo_05 = wind_mapo['M05']
wind_mapo_05_list = wind_mapo_05.tolist()

res = 0
for i in wind_mapo_05_list:
  res+=i

avg_mapo_05 = round(res/(len(wind_mapo_05_list)),2)
wind_mapo_avg.append(avg_mapo_05)

# %% [markdown]
# ## 6월

# %%
wind_mapo_06 = wind_mapo['M06']
wind_mapo_06_list = wind_mapo_06.tolist()

res = 0
for i in wind_mapo_06_list:
  res+=i

avg_mapo_06 = round(res/(len(wind_mapo_06_list)),2)
wind_mapo_avg.append(avg_mapo_06)

# %% [markdown]
# ## 7월

# %%
wind_mapo_07 = wind_mapo['M07']
wind_mapo_07_list = wind_mapo_07.tolist()

res = 0
for i in wind_mapo_07_list:
  res+=i

avg_mapo_07 = round(res/(len(wind_mapo_07_list)),2)
wind_mapo_avg.append(avg_mapo_07)

# %% [markdown]
# ## 8월

# %%
wind_mapo_08 = wind_mapo['M08']
wind_mapo_08_list = wind_mapo_08.tolist()

res = 0
for i in wind_mapo_08_list:
  res+=i

avg_mapo_08 = round(res/(len(wind_mapo_08_list)),2)
wind_mapo_avg.append(avg_mapo_08)

# %% [markdown]
# ## 9월

# %%
wind_mapo_09 = wind_mapo['M09']
wind_mapo_09_list = wind_mapo_09.tolist()

res = 0
for i in wind_mapo_09_list:
  res+=i

avg_mapo_09 = round(res/(len(wind_mapo_09_list)),2)
wind_mapo_avg.append(avg_mapo_09)

# %% [markdown]
# ## 10월

# %%
wind_mapo_10 = wind_mapo['M10']
wind_mapo_10_list = wind_mapo_10.tolist()

res = 0
for i in wind_mapo_10_list:
  res+=i

avg_mapo_10 = round(res/(len(wind_mapo_10_list)),2)
wind_mapo_avg.append(avg_mapo_10)

# %% [markdown]
# ## 11월

# %%
wind_mapo_11 = wind_mapo['M11']
wind_mapo_11_list = wind_mapo_11.tolist()

res = 0
for i in wind_mapo_11_list:
  res+=i

avg_mapo_11 = round(res/(len(wind_mapo_11_list)),2)
wind_mapo_avg.append(avg_mapo_11)

# %% [markdown]
# ## 12월

# %%
wind_mapo_12 = wind_mapo['M12']
wind_mapo_12_list = wind_mapo_12.tolist()

res = 0
for i in wind_mapo_12_list:
  res+=i

avg_mapo_12 = round(res/(len(wind_mapo_12_list)),2)
wind_mapo_avg.append(avg_mapo_12)

# %%
print("마포구 1월~12월 평균 풍속: {}".format(wind_mapo_avg))
# Out:
# 마포구 1월~12월 평균 풍속: [1.77, 2.01, 2.18, 2.03, 1.87, 1.77, 1.78, 1.82, 1.66, 1.68, 1.96, 1.77]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_mapo_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('마포구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 서대문구

# %%
wind_sdm = wind[wind["ADDR_KOR"].str.contains('서대문구')]
wind_sdm
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 25   1.8  2.8  2.1  ...  553500.189  01(풍속평균).shp  POINT (193817.650 553500.189)
# 53   1.7  1.5  2.0  ...  552013.373  01(풍속평균).shp  POINT (195283.151 552013.373)
# 77   1.7  1.9  2.6  ...  553500.189  01(풍속평균).shp  POINT (193817.650 553500.189)
# 112  1.5  1.7  1.9  ...  552013.373  01(풍속평균).shp  POINT (195283.151 552013.373)
# 136  2.1  1.9  1.9  ...  553500.189  01(풍속평균).shp  POINT (193817.650 553500.189)
# 145  2.0  1.8  2.3  ...  553500.189  01(풍속평균).shp  POINT (193817.650 553500.189)
# 173  0.0  1.6  2.0  ...  552013.373  01(풍속평균).shp  POINT (195283.151 552013.373)
# 197  1.9  2.0  2.8  ...  553500.189  01(풍속평균).shp  POINT (193817.650 553500.189)
# 225  1.7  1.6  2.0  ...  552013.373  01(풍속평균).shp  POINT (195283.151 552013.373)
# 245  1.8  2.0  1.8  ...  553500.189  01(풍속평균).shp  POINT (193817.650 553500.189)
# 274  1.5  1.6  1.7  ...  552013.373  01(풍속평균).shp  POINT (195283.151 552013.373)
# ...

# %%
#서대문구 월별 평균 리스트
wind_sdm_avg = []

# %% [markdown]
# ## 1월

# %%
wind_sdm_01 = wind_sdm['M01']
wind_sdm_01_list = wind_sdm_01.tolist()

res = 0
for i in wind_sdm_01_list:
  res+=i

avg_sdm_01 = round(res/(len(wind_sdm_01_list)),2)
wind_sdm_avg.append(avg_sdm_01)

# %% [markdown]
# ## 2월

# %%
wind_sdm_02 = wind_sdm['M02']
wind_sdm_02_list = wind_sdm_02.tolist()

res = 0
for i in wind_sdm_02_list:
  res+=i

avg_sdm_02 = round(res/(len(wind_sdm_02_list)),2)
wind_sdm_avg.append(avg_sdm_02)

# %% [markdown]
# ## 3월

# %%
wind_sdm_03 = wind_sdm['M03']
wind_sdm_03_list = wind_sdm_03.tolist()

res = 0
for i in wind_sdm_03_list:
  res+=i

avg_sdm_03 = round(res/(len(wind_sdm_03_list)),2)
wind_sdm_avg.append(avg_sdm_03)

# %% [markdown]
# ## 4월

# %%
wind_sdm_04 = wind_sdm['M04']
wind_sdm_04_list = wind_sdm_04.tolist()

res = 0
for i in wind_sdm_04_list:
  res+=i

avg_sdm_04 = round(res/(len(wind_sdm_04_list)),2)
wind_sdm_avg.append(avg_sdm_04)

# %% [markdown]
# ## 5월

# %%
wind_sdm_05 = wind_sdm['M05']
wind_sdm_05_list = wind_sdm_05.tolist()

res = 0
for i in wind_sdm_05_list:
  res+=i

avg_sdm_05 = round(res/(len(wind_sdm_05_list)),2)
wind_sdm_avg.append(avg_sdm_05)

# %% [markdown]
# ## 6월

# %%
wind_sdm_06 = wind_sdm['M06']
wind_sdm_06_list = wind_sdm_06.tolist()

res = 0
for i in wind_sdm_06_list:
  res+=i

avg_sdm_06 = round(res/(len(wind_sdm_06_list)),2)
wind_sdm_avg.append(avg_sdm_06)

# %% [markdown]
# ## 7월

# %%
wind_sdm_07 = wind_sdm['M07']
wind_sdm_07_list = wind_sdm_07.tolist()

res = 0
for i in wind_sdm_07_list:
  res+=i

avg_sdm_07 = round(res/(len(wind_sdm_07_list)),2)
wind_sdm_avg.append(avg_sdm_07)

# %% [markdown]
# ## 8월

# %%
wind_sdm_08 = wind_sdm['M08']
wind_sdm_08_list = wind_sdm_08.tolist()

res = 0
for i in wind_sdm_08_list:
  res+=i

avg_sdm_08 = round(res/(len(wind_sdm_08_list)),2)
wind_sdm_avg.append(avg_sdm_08)

# %% [markdown]
# ## 9월

# %%
wind_sdm_09 = wind_sdm['M09']
wind_sdm_09_list = wind_sdm_09.tolist()

res = 0
for i in wind_sdm_09_list:
  res+=i

avg_sdm_09 = round(res/(len(wind_sdm_09_list)),2)
wind_sdm_avg.append(avg_sdm_09)

# %% [markdown]
# ## 10월

# %%
wind_sdm_10 = wind_sdm['M10']
wind_sdm_10_list = wind_sdm_10.tolist()

res = 0
for i in wind_sdm_10_list:
  res+=i

avg_sdm_10 = round(res/(len(wind_sdm_10_list)),2)
wind_sdm_avg.append(avg_sdm_10)

# %% [markdown]
# ## 11월

# %%
wind_sdm_11 = wind_sdm['M11']
wind_sdm_11_list = wind_sdm_11.tolist()

res = 0
for i in wind_sdm_11_list:
  res+=i

avg_sdm_11 = round(res/(len(wind_sdm_11_list)),2)
wind_sdm_avg.append(avg_sdm_11)

# %% [markdown]
# ## 12월

# %%
wind_sdm_12 = wind_sdm['M12']
wind_sdm_12_list = wind_sdm_12.tolist()

res = 0
for i in wind_sdm_12_list:
  res+=i

avg_sdm_12 = round(res/(len(wind_sdm_12_list)),2)
wind_sdm_avg.append(avg_sdm_12)

# %%
print("서대문구 1월~12월 평균 풍속: {}".format(wind_sdm_avg))
# Out:
# 서대문구 1월~12월 평균 풍속: [1.58, 1.77, 1.89, 1.9, 1.68, 1.51, 1.67, 1.71, 1.59, 1.54, 1.82, 1.57]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_sdm_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('서대문구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 은평구

# %%
wind_ep = wind[wind["ADDR_KOR"].str.contains('은평구')]
wind_ep
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 0    1.7  2.1  2.7  ...  556471.835  01(풍속평균).shp  POINT (194349.346 556471.835)
# 3    0.0  2.0  2.4  ...  555971.977  01(풍속평균).shp  POINT (193704.957 555971.977)
# 37   2.1  2.3  2.6  ...  555971.977  01(풍속평균).shp  POINT (193704.957 555971.977)
# 57   2.0  1.7  2.4  ...  556471.835  01(풍속평균).shp  POINT (194349.346 556471.835)
# 88   1.9  2.1  2.5  ...  555971.977  01(풍속평균).shp  POINT (193704.957 555971.977)
# 116  0.7  0.9  1.4  ...  556471.835  01(풍속평균).shp  POINT (194349.346 556471.835)
# 177  0.0  1.9  2.4  ...  556471.835  01(풍속평균).shp  POINT (194349.346 556471.835)
# 208  2.0  2.0  2.5  ...  555971.977  01(풍속평균).shp  POINT (193704.957 555971.977)
# 257  1.6  1.9  1.9  ...  555971.977  01(풍속평균).shp  POINT (193704.957 555971.977)
# 278  0.7  1.0  1.1  ...  556471.835  01(풍속평균).shp  POINT (194349.346 556471.835)
# 315  1.5  1.8  1.6  ...  555971.977  01(풍속평균).shp  POINT (193704.957 555971.977)
# ...

# %%
#은평구 월별 평균 리스트
wind_ep_avg = []

# %% [markdown]
# ## 1월

# %%
wind_ep_01 = wind_ep['M01']
wind_ep_01_list = wind_ep_01.tolist()

res = 0
for i in wind_ep_01_list:
  res+=i

avg_ep_01 = round(res/(len(wind_ep_01_list)),2)
wind_ep_avg.append(avg_ep_01)

# %% [markdown]
# ## 2월

# %%
wind_ep_02 = wind_ep['M02']
wind_ep_02_list = wind_ep_02.tolist()

res = 0
for i in wind_ep_02_list:
  res+=i

avg_ep_02 = round(res/(len(wind_ep_02_list)),2)
wind_ep_avg.append(avg_ep_02)

# %% [markdown]
# ## 3월

# %%
wind_ep_03 = wind_ep['M03']
wind_ep_03_list = wind_ep_03.tolist()

res = 0
for i in wind_ep_03_list:
  res+=i

avg_ep_03 = round(res/(len(wind_ep_03_list)),2)
wind_ep_avg.append(avg_ep_03)

# %% [markdown]
# ## 4월

# %%
wind_ep_04 = wind_ep['M04']
wind_ep_04_list = wind_ep_04.tolist()

res = 0
for i in wind_ep_04_list:
  res+=i

avg_ep_04 = round(res/(len(wind_ep_04_list)),2)
wind_ep_avg.append(avg_ep_04)

# %% [markdown]
# ## 5월

# %%
wind_ep_05 = wind_ep['M05']
wind_ep_05_list = wind_ep_05.tolist()

res = 0
for i in wind_ep_05_list:
  res+=i

avg_ep_05 = round(res/(len(wind_ep_05_list)),2)
wind_ep_avg.append(avg_ep_05)

# %% [markdown]
# ## 6월

# %%
wind_ep_06 = wind_ep['M06']
wind_ep_06_list = wind_ep_06.tolist()

res = 0
for i in wind_ep_06_list:
  res+=i

avg_ep_06 = round(res/(len(wind_ep_06_list)),2)
wind_ep_avg.append(avg_ep_06)

# %% [markdown]
# ## 7월

# %%
wind_ep_07 = wind_ep['M07']
wind_ep_07_list = wind_ep_07.tolist()

res = 0
for i in wind_ep_07_list:
  res+=i

avg_ep_07 = round(res/(len(wind_ep_07_list)),2)
wind_ep_avg.append(avg_ep_07)

# %% [markdown]
# ## 8월

# %%
wind_ep_08 = wind_ep['M08']
wind_ep_08_list = wind_ep_08.tolist()

res = 0
for i in wind_ep_08_list:
  res+=i

avg_ep_08 = round(res/(len(wind_ep_08_list)),2)
wind_ep_avg.append(avg_ep_08)

# %% [markdown]
# ## 9월

# %%
wind_ep_09 = wind_ep['M09']
wind_ep_09_list = wind_ep_09.tolist()

res = 0
for i in wind_ep_09_list:
  res+=i

avg_ep_09 = round(res/(len(wind_ep_09_list)),2)
wind_ep_avg.append(avg_ep_09)

# %% [markdown]
# ## 10월

# %%
wind_ep_10 = wind_ep['M10']
wind_ep_10_list = wind_ep_10.tolist()

res = 0
for i in wind_ep_10_list:
  res+=i

avg_ep_10 = round(res/(len(wind_ep_10_list)),2)
wind_ep_avg.append(avg_ep_10)

# %% [markdown]
# ## 11월

# %%
wind_ep_11 = wind_ep['M11']
wind_ep_11_list = wind_ep_11.tolist()

res = 0
for i in wind_ep_11_list:
  res+=i

avg_ep_11 = round(res/(len(wind_ep_11_list)),2)
wind_ep_avg.append(avg_ep_11)

# %% [markdown]
# ## 12월

# %%
wind_ep_12 = wind_ep['M12']
wind_ep_12_list = wind_ep_12.tolist()

res = 0
for i in wind_ep_11_list:
  res+=i

avg_ep_12 = round(res/(len(wind_ep_12_list)),2)
wind_ep_avg.append(avg_ep_12)

# %%
print("은평구 1월~12월 평균 풍속: {}".format(wind_ep_avg))
# Out:
# 은평구 1월~12월 평균 풍속: [1.26, 1.61, 1.88, 1.87, 1.69, 1.54, 1.58, 1.52, 1.28, 1.31, 1.6, 1.6]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_ep_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('은평구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 노원구

# %%
wind_nowon = wind[wind["ADDR_KOR"].str.contains('노원구')]
wind_nowon
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 28   0.7  0.9  1.1  ...  559885.767  01(풍속평균).shp  POINT (205851.059 559885.767)
# 48   1.8  1.6  2.6  ...  557764.395  01(풍속평균).shp  POINT (207891.686 557764.395)
# 79   1.0  1.1  1.5  ...  559885.767  01(풍속평균).shp  POINT (205851.059 559885.767)
# 101  1.8  2.2  2.5  ...  557764.395  01(풍속평균).shp  POINT (207891.686 557764.395)
# 148  1.1  1.1  1.4  ...  559885.767  01(풍속평균).shp  POINT (205851.059 559885.767)
# 169  0.0  1.3  2.2  ...  557764.395  01(풍속평균).shp  POINT (207891.686 557764.395)
# 199  1.0  1.1  1.4  ...  559885.767  01(풍속평균).shp  POINT (205851.059 559885.767)
# 220  1.5  1.6  2.1  ...  557764.395  01(풍속평균).shp  POINT (207891.686 557764.395)
# 248  0.9  1.1  1.2  ...  559885.767  01(풍속평균).shp  POINT (205851.059 559885.767)
# 269  1.1  1.3  1.4  ...  557764.395  01(풍속평균).shp  POINT (207891.686 557764.395)
# 302  0.9  1.1  1.1  ...  559885.767  01(풍속평균).shp  POINT (205851.059 559885.767)
# ...

# %%
#노원구 월별 평균 리스트
wind_nowon_avg = []

# %% [markdown]
# ## 1월

# %%
wind_nowon_01 = wind_nowon['M01']
wind_nowon_01_list = wind_nowon_01.tolist()

res = 0
for i in wind_nowon_01_list:
  res+=i

avg_nowon_01 = round(res/(len(wind_nowon_01_list)),2)
wind_nowon_avg.append(avg_nowon_01)

# %% [markdown]
# ## 2월

# %%
wind_nowon_02 = wind_nowon['M02']
wind_nowon_02_list = wind_nowon_02.tolist()

res = 0
for i in wind_nowon_02_list:
  res+=i

avg_nowon_02 = round(res/(len(wind_nowon_02_list)),2)
wind_nowon_avg.append(avg_nowon_02)

# %% [markdown]
# ## 3월

# %%
wind_nowon_03 = wind_nowon['M03']
wind_nowon_03_list = wind_nowon_03.tolist()

res = 0
for i in wind_nowon_03_list:
  res+=i

avg_nowon_03 = round(res/(len(wind_nowon_03_list)),2)
wind_nowon_avg.append(avg_nowon_03)

# %% [markdown]
# ## 4월

# %%
wind_nowon_04 = wind_nowon['M04']
wind_nowon_04_list = wind_nowon_04.tolist()

res = 0
for i in wind_nowon_04_list:
  res+=i

avg_nowon_04 = round(res/(len(wind_nowon_04_list)),2)
wind_nowon_avg.append(avg_nowon_04)

# %% [markdown]
# ## 5월

# %%
wind_nowon_05 = wind_nowon['M05']
wind_nowon_05_list = wind_nowon_05.tolist()

res = 0
for i in wind_nowon_05_list:
  res+=i

avg_nowon_05 = round(res/(len(wind_nowon_05_list)),2)
wind_nowon_avg.append(avg_nowon_05)

# %% [markdown]
# ## 6월

# %%
wind_nowon_06 = wind_nowon['M06']
wind_nowon_06_list = wind_nowon_06.tolist()

res = 0
for i in wind_nowon_06_list:
  res+=i

avg_nowon_06 = round(res/(len(wind_nowon_06_list)),2)
wind_nowon_avg.append(avg_nowon_06)

# %% [markdown]
# ## 7월

# %%
wind_nowon_07 = wind_nowon['M07']
wind_nowon_07_list = wind_nowon_07.tolist()

res = 0
for i in wind_nowon_07_list:
  res+=i

avg_nowon_07 = round(res/(len(wind_nowon_07_list)),2)
wind_nowon_avg.append(avg_nowon_07)

# %% [markdown]
# ## 8월

# %%
wind_nowon_08 = wind_nowon['M08']
wind_nowon_08_list = wind_nowon_08.tolist()

res = 0
for i in wind_nowon_08_list:
  res+=i

avg_nowon_08 = round(res/(len(wind_nowon_08_list)),2)
wind_nowon_avg.append(avg_nowon_08)

# %% [markdown]
# ## 9월

# %%
wind_nowon_09 = wind_nowon['M09']
wind_nowon_09_list = wind_nowon_09.tolist()

res = 0
for i in wind_nowon_09_list:
  res+=i

avg_nowon_09 = round(res/(len(wind_nowon_09_list)),2)
wind_nowon_avg.append(avg_nowon_09)

# %% [markdown]
# ## 10월

# %%
wind_nowon_10 = wind_nowon['M10']
wind_nowon_10_list = wind_nowon_10.tolist()

res = 0
for i in wind_nowon_10_list:
  res+=i

avg_nowon_10 = round(res/(len(wind_nowon_10_list)),2)
wind_nowon_avg.append(avg_nowon_10)

# %% [markdown]
# ## 11월

# %%
wind_nowon_11 = wind_nowon['M11']
wind_nowon_11_list = wind_nowon_11.tolist()

res = 0
for i in wind_nowon_11_list:
  res+=i

avg_nowon_11 = round(res/(len(wind_nowon_11_list)),2)
wind_nowon_avg.append(avg_nowon_11)

# %% [markdown]
# ## 12월

# %%
wind_nowon_12 = wind_nowon['M12']
wind_nowon_12_list = wind_nowon_12.tolist()

res = 0
for i in wind_nowon_12_list:
  res+=i

avg_nowon_12 = round(res/(len(wind_nowon_12_list)),2)
wind_nowon_avg.append(avg_nowon_12)

# %%
print("노원구 1월~12월 평균 풍속: {}".format(wind_nowon_avg))
# Out:
# 노원구 1월~12월 평균 풍속: [1.08, 1.25, 1.54, 1.47, 1.32, 1.21, 1.11, 1.12, 1.02, 0.97, 1.16, 1.04]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_nowon_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('노원구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 도봉구

# %%
wind_dobong = wind[wind["ADDR_KOR"].str.contains('도봉구')]
wind_dobong
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 2    1.2  1.2  1.5  ...  563251.524  01(풍속평균).shp  POINT (203801.837 563251.524)
# 20   1.2  1.2  1.6  ...  563251.524  01(풍속평균).shp  POINT (203801.837 563251.524)
# 47   1.1  1.0  1.7  ...  562633.146  01(풍속평균).shp  POINT (203105.658 562633.146)
# 71   1.1  1.2  1.5  ...  563251.524  01(풍속평균).shp  POINT (203801.837 563251.524)
# 100  1.1  1.2  1.5  ...  562633.146  01(풍속평균).shp  POINT (203105.658 562633.146)
# 130  1.0  1.1  1.3  ...  563251.524  01(풍속평균).shp  POINT (203801.837 563251.524)
# 168  0.0  0.9  1.3  ...  562633.146  01(풍속평균).shp  POINT (203105.658 562633.146)
# 191  1.0  1.1  1.4  ...  563251.524  01(풍속평균).shp  POINT (203801.837 563251.524)
# 219  0.8  0.9  1.2  ...  562633.146  01(풍속평균).shp  POINT (203105.658 562633.146)
# 240  1.0  1.1  1.2  ...  563251.524  01(풍속평균).shp  POINT (203801.837 563251.524)
# 268  1.2  1.3  1.5  ...  562633.146  01(풍속평균).shp  POINT (203105.658 562633.146)
# ...

# %%
#도봉구 월별 평균 리스트
wind_dobong_avg = []

# %% [markdown]
# ## 1월

# %%
wind_dobong_01 = wind_dobong['M01']
wind_dobong_01_list = wind_dobong_01.tolist()

res = 0
for i in wind_dobong_01_list:
  res+=i

avg_dobong_01 = round(res/(len(wind_dobong_01_list)),2)
wind_dobong_avg.append(avg_dobong_01)

# %% [markdown]
# ## 2월

# %%
wind_dobong_02 = wind_dobong['M02']
wind_dobong_02_list = wind_dobong_02.tolist()

res = 0
for i in wind_dobong_02_list:
  res+=i

avg_dobong_02 = round(res/(len(wind_dobong_02_list)),2)
wind_dobong_avg.append(avg_dobong_02)

# %% [markdown]
# ## 3월

# %%
wind_dobong_03 = wind_dobong['M03']
wind_dobong_03_list = wind_dobong_03.tolist()

res = 0
for i in wind_dobong_03_list:
  res+=i

avg_dobong_03 = round(res/(len(wind_dobong_03_list)),2)
wind_dobong_avg.append(avg_dobong_03)

# %% [markdown]
# ## 4월

# %%
wind_dobong_04 = wind_dobong['M04']
wind_dobong_04_list = wind_dobong_04.tolist()

res = 0
for i in wind_dobong_04_list:
  res+=i

avg_dobong_04 = round(res/(len(wind_dobong_04_list)),2)
wind_dobong_avg.append(avg_dobong_04)

# %% [markdown]
# ## 5월

# %%
wind_dobong_05 = wind_dobong['M05']
wind_dobong_05_list = wind_dobong_05.tolist()

res = 0
for i in wind_dobong_05_list:
  res+=i

avg_dobong_05 = round(res/(len(wind_dobong_05_list)),2)
wind_dobong_avg.append(avg_dobong_05)

# %% [markdown]
# ## 6월

# %%
wind_dobong_06 = wind_dobong['M06']
wind_dobong_06_list = wind_dobong_06.tolist()

res = 0
for i in wind_dobong_06_list:
  res+=i

avg_dobong_06 = round(res/(len(wind_dobong_06_list)),2)
wind_dobong_avg.append(avg_dobong_06)

# %% [markdown]
# ## 7월

# %%
wind_dobong_07 = wind_dobong['M07']
wind_dobong_07_list = wind_dobong_07.tolist()

res = 0
for i in wind_dobong_07_list:
  res+=i

avg_dobong_07 = round(res/(len(wind_dobong_07_list)),2)
wind_dobong_avg.append(avg_dobong_07)

# %% [markdown]
# ## 8월

# %%
wind_dobong_08 = wind_dobong['M08']
wind_dobong_08_list = wind_dobong_08.tolist()

res = 0
for i in wind_dobong_08_list:
  res+=i

avg_dobong_08 = round(res/(len(wind_dobong_08_list)),2)
wind_dobong_avg.append(avg_dobong_08)

# %% [markdown]
# ## 9월

# %%
wind_dobong_09 = wind_dobong['M09']
wind_dobong_09_list = wind_dobong_09.tolist()

res = 0
for i in wind_dobong_09_list:
  res+=i

avg_dobong_09 = round(res/(len(wind_dobong_09_list)),2)
wind_dobong_avg.append(avg_dobong_09)

# %% [markdown]
# ## 10월

# %%
wind_dobong_10 = wind_dobong['M10']
wind_dobong_10_list = wind_dobong_10.tolist()

res = 0
for i in wind_dobong_10_list:
  res+=i

avg_dobong_10 = round(res/(len(wind_dobong_10_list)),2)
wind_dobong_avg.append(avg_dobong_10)

# %% [markdown]
# ## 11월

# %%
wind_dobong_11 = wind_dobong['M11']
wind_dobong_11_list = wind_dobong_11.tolist()

res = 0
for i in wind_dobong_11_list:
  res+=i

avg_dobong_11 = round(res/(len(wind_dobong_11_list)),2)
wind_dobong_avg.append(avg_dobong_11)

# %% [markdown]
# ## 12월

# %%
wind_dobong_12 = wind_dobong['M12']
wind_dobong_12_list = wind_dobong_12.tolist()

res = 0
for i in wind_dobong_12_list:
  res+=i

avg_dobong_12 = round(res/(len(wind_dobong_12_list)),2)
wind_dobong_avg.append(avg_dobong_12)

# %%
print("도봉구 1월~12월 평균 풍속: {}".format(wind_dobong_avg))
# Out:
# 도봉구 1월~12월 평균 풍속: [0.96, 1.08, 1.34, 1.25, 1.11, 0.99, 0.91, 0.77, 0.67, 0.73, 0.92, 0.87]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_dobong_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('도봉구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 강북구

# %%
wind_gangbuk = wind[wind["ADDR_KOR"].str.contains('강북구')]
wind_gangbuk
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 12   0.8  1.1  1.6  ...  559303.226  01(풍속평균).shp  POINT (200150.038 559303.226)
# 30   1.3  1.6  1.9  ...  557632.355  01(풍속평균).shp  POINT (202101.196 557632.355)
# 63   1.8  1.5  2.5  ...  559303.226  01(풍속평균).shp  POINT (200150.038 559303.226)
# 81   1.3  1.5  1.9  ...  557632.355  01(풍속평균).shp  POINT (202101.196 557632.355)
# 123  1.8  2.0  2.5  ...  559303.226  01(풍속평균).shp  POINT (200150.038 559303.226)
# 150  0.0  1.4  1.8  ...  557632.355  01(풍속평균).shp  POINT (202101.196 557632.355)
# 183  0.0  1.3  1.8  ...  559303.226  01(풍속평균).shp  POINT (200150.038 559303.226)
# 201  1.2  1.4  1.8  ...  557632.355  01(풍속평균).shp  POINT (202101.196 557632.355)
# 232  1.6  1.6  2.0  ...  559303.226  01(풍속평균).shp  POINT (200150.038 559303.226)
# 250  1.3  1.4  1.7  ...  557632.355  01(풍속평균).shp  POINT (202101.196 557632.355)
# 285  1.8  2.0  2.3  ...  559303.226  01(풍속평균).shp  POINT (200150.038 559303.226)
# ...

# %%
#강북구 월별 평균 리스트
wind_gangbuk_avg = []

# %% [markdown]
# ## 1월

# %%
wind_gangbuk_01 = wind_gangbuk['M01']
wind_gangbuk_01_list = wind_gangbuk_01.tolist()

res = 0
for i in wind_gangbuk_01_list:
  res+=i

avg_gangbuk_01 = round(res/(len(wind_gangbuk_01_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_01)

# %% [markdown]
# ## 2월

# %%
wind_gangbuk_02 = wind_gangbuk['M02']
wind_gangbuk_02_list = wind_gangbuk_02.tolist()

res = 0
for i in wind_gangbuk_02_list:
  res+=i

avg_gangbuk_02 = round(res/(len(wind_gangbuk_02_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_02)

# %% [markdown]
# ## 3월

# %%
wind_gangbuk_03 = wind_gangbuk['M03']
wind_gangbuk_03_list = wind_gangbuk_03.tolist()

res = 0
for i in wind_gangbuk_03_list:
  res+=i

avg_gangbuk_03 = round(res/(len(wind_gangbuk_03_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_03)

# %% [markdown]
# ## 4월

# %%
wind_gangbuk_04 = wind_gangbuk['M04']
wind_gangbuk_04_list = wind_gangbuk_04.tolist()

res = 0
for i in wind_gangbuk_04_list:
  res+=i

avg_gangbuk_04 = round(res/(len(wind_gangbuk_04_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_04)

# %% [markdown]
# ## 5월

# %%
wind_gangbuk_05 = wind_gangbuk['M05']
wind_gangbuk_05_list = wind_gangbuk_05.tolist()

res = 0
for i in wind_gangbuk_05_list:
  res+=i

avg_gangbuk_05 = round(res/(len(wind_gangbuk_05_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_05)

# %% [markdown]
# ## 6월

# %%
wind_gangbuk_06 = wind_gangbuk['M06']
wind_gangbuk_06_list = wind_gangbuk_06.tolist()

res = 0
for i in wind_gangbuk_06_list:
  res+=i

avg_gangbuk_06 = round(res/(len(wind_gangbuk_06_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_06)

# %% [markdown]
# ## 7월

# %%
wind_gangbuk_07 = wind_gangbuk['M07']
wind_gangbuk_07_list = wind_gangbuk_07.tolist()

res = 0
for i in wind_gangbuk_07_list:
  res+=i

avg_gangbuk_07 = round(res/(len(wind_gangbuk_07_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_07)

# %% [markdown]
# ## 8월

# %%
wind_gangbuk_08 = wind_gangbuk['M08']
wind_gangbuk_08_list = wind_gangbuk_08.tolist()

res = 0
for i in wind_gangbuk_08_list:
  res+=i

avg_gangbuk_08 = round(res/(len(wind_gangbuk_08_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_08)

# %% [markdown]
# ## 9월

# %%
wind_gangbuk_09 = wind_gangbuk['M09']
wind_gangbuk_09_list = wind_gangbuk_09.tolist()

res = 0
for i in wind_gangbuk_09_list:
  res+=i

avg_gangbuk_09 = round(res/(len(wind_gangbuk_09_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_09)

# %% [markdown]
# ## 10월

# %%
wind_gangbuk_10 = wind_gangbuk['M10']
wind_gangbuk_10_list = wind_gangbuk_10.tolist()

res = 0
for i in wind_gangbuk_10_list:
  res+=i

avg_gangbuk_10 = round(res/(len(wind_gangbuk_10_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_10)

# %% [markdown]
# ## 11월

# %%
wind_gangbuk_11 = wind_gangbuk['M11']
wind_gangbuk_11_list = wind_gangbuk_11.tolist()

res = 0
for i in wind_gangbuk_11_list:
  res+=i

avg_gangbuk_11 = round(res/(len(wind_gangbuk_11_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_11)

# %% [markdown]
# ## 12월

# %%
wind_gangbuk_12 = wind_gangbuk['M12']
wind_gangbuk_12_list = wind_gangbuk_12.tolist()

res = 0
for i in wind_gangbuk_12_list:
  res+=i

avg_gangbuk_12 = round(res/(len(wind_gangbuk_12_list)),2)
wind_gangbuk_avg.append(avg_gangbuk_12)

# %%
print("강북구 1월~12월 평균 풍속: {}".format(wind_gangbuk_avg))
# Out:
# 강북구 1월~12월 평균 풍속: [1.31, 1.6, 1.92, 1.86, 1.83, 1.71, 1.59, 1.57, 1.4, 1.37, 1.52, 1.37]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_gangbuk_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('강북구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 성북구

# %%
wind_sb = wind[wind["ADDR_KOR"].str.contains('성북구')]
wind_sb
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 19   1.1  1.5  1.4  ...  555504.066  01(풍속평균).shp  POINT (203108.332 555504.066)
# 55   1.4  1.3  1.9  ...  556772.939  01(풍속평균).shp  POINT (199937.956 556772.939)
# 70   1.4  1.5  1.8  ...  555504.066  01(풍속평균).shp  POINT (203108.332 555504.066)
# 114  1.3  1.5  2.0  ...  556772.939  01(풍속평균).shp  POINT (199937.956 556772.939)
# 129  1.4  1.3  1.4  ...  555504.066  01(풍속평균).shp  POINT (203108.332 555504.066)
# 139  0.0  1.2  1.4  ...  555504.066  01(풍속평균).shp  POINT (203108.332 555504.066)
# 175  0.0  1.4  2.2  ...  556772.939  01(풍속평균).shp  POINT (199937.956 556772.939)
# 190  1.3  1.3  1.7  ...  555504.066  01(풍속평균).shp  POINT (203108.332 555504.066)
# 227  1.5  1.7  2.3  ...  556772.939  01(풍속평균).shp  POINT (199937.956 556772.939)
# 239  1.4  1.5  1.6  ...  555504.066  01(풍속평균).shp  POINT (203108.332 555504.066)
# 276  1.3  1.6  1.8  ...  556772.939  01(풍속평균).shp  POINT (199937.956 556772.939)
# ...

# %%
#성북구 월별 평균 리스트
wind_sb_avg = []

# %% [markdown]
# ## 1월

# %%
wind_sb_01 = wind_sb['M01']
wind_sb_01_list = wind_sb_01.tolist()

res = 0
for i in wind_sb_01_list:
  res+=i

avg_sb_01 = round(res/(len(wind_sb_01_list)),2)
wind_sb_avg.append(avg_sb_01)

# %% [markdown]
# ## 2월

# %%
wind_sb_02 = wind_sb['M02']
wind_sb_02_list = wind_sb_02.tolist()

res = 0
for i in wind_sb_02_list:
  res+=i

avg_sb_02 = round(res/(len(wind_sb_02_list)),2)
wind_sb_avg.append(avg_sb_02)

# %% [markdown]
# ## 3월

# %%
wind_sb_03 = wind_sb['M03']
wind_sb_03_list = wind_sb_03.tolist()

res = 0
for i in wind_sb_03_list:
  res+=i

avg_sb_03 = round(res/(len(wind_sb_03_list)),2)
wind_sb_avg.append(avg_sb_03)

# %% [markdown]
# ## 4월

# %%
wind_sb_04 = wind_sb['M04']
wind_sb_04_list = wind_sb_04.tolist()

res = 0
for i in wind_sb_04_list:
  res+=i

avg_sb_04 = round(res/(len(wind_sb_04_list)),2)
wind_sb_avg.append(avg_sb_04)

# %% [markdown]
# ## 5월

# %%
wind_sb_05 = wind_sb['M05']
wind_sb_05_list = wind_sb_05.tolist()

res = 0
for i in wind_sb_05_list:
  res+=i

avg_sb_05 = round(res/(len(wind_sb_05_list)),2)
wind_sb_avg.append(avg_sb_05)

# %% [markdown]
# ## 6월

# %%
wind_sb_06 = wind_sb['M06']
wind_sb_06_list = wind_sb_06.tolist()

res = 0
for i in wind_sb_06_list:
  res+=i

avg_sb_06 = round(res/(len(wind_sb_06_list)),2)
wind_sb_avg.append(avg_sb_06)

# %% [markdown]
# ## 7월

# %%
wind_sb_07 = wind_sb['M07']
wind_sb_07_list = wind_sb_07.tolist()

res = 0
for i in wind_sb_07_list:
  res+=i

avg_sb_07 = round(res/(len(wind_sb_07_list)),2)
wind_sb_avg.append(avg_sb_07)

# %% [markdown]
# ## 8월

# %%
wind_sb_08 = wind_sb['M08']
wind_sb_08_list = wind_sb_08.tolist()

res = 0
for i in wind_sb_08_list:
  res+=i

avg_sb_08 = round(res/(len(wind_sb_08_list)),2)
wind_sb_avg.append(avg_sb_08)

# %% [markdown]
# ## 9월

# %%
wind_sb_09 = wind_sb['M09']
wind_sb_09_list = wind_sb_09.tolist()

res = 0
for i in wind_sb_09_list:
  res+=i

avg_sb_09 = round(res/(len(wind_sb_09_list)),2)
wind_sb_avg.append(avg_sb_09)

# %% [markdown]
# ## 10월

# %%
wind_sb_10 = wind_sb['M10']
wind_sb_10_list = wind_sb_10.tolist()

res = 0
for i in wind_sb_10_list:
  res+=i

avg_sb_10 = round(res/(len(wind_sb_10_list)),2)
wind_sb_avg.append(avg_sb_10)

# %% [markdown]
# ## 11월

# %%
wind_sb_11 = wind_sb['M11']
wind_sb_11_list = wind_sb_11.tolist()

res = 0
for i in wind_sb_11_list:
  res+=i

avg_sb_11 = round(res/(len(wind_sb_11_list)),2)
wind_sb_avg.append(avg_sb_11)

# %% [markdown]
# ## 12월

# %%
wind_sb_12 = wind_sb['M12']
wind_sb_12_list = wind_sb_12.tolist()

res = 0
for i in wind_sb_12_list:
  res+=i

avg_sb_12 = round(res/(len(wind_sb_12_list)),2)
wind_sb_avg.append(avg_sb_12)

# %%
print("성북구 1월~12월 평균 풍속: {}".format(wind_sb_avg))
# Out:
# 성북구 1월~12월 평균 풍속: [1.18, 1.45, 1.69, 1.67, 1.61, 1.53, 1.48, 1.46, 1.36, 1.21, 1.43, 1.21]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_sb_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('성북구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 중랑구

# %%
wind_jr = wind[wind["ADDR_KOR"].str.contains('중랑구')]
wind_jr
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 34   1.5  2.0  2.3  ...  552671.138  01(풍속평균).shp  POINT (207534.143 552671.138)
# 50   1.8  1.7  2.4  ...  553780.275  01(풍속평균).shp  POINT (207851.075 553780.275)
# 85   1.7  1.9  2.3  ...  552671.138  01(풍속평균).shp  POINT (207534.143 552671.138)
# 109  1.9  2.2  2.6  ...  553780.275  01(풍속평균).shp  POINT (207851.075 553780.275)
# 154  0.0  1.7  2.2  ...  552671.138  01(풍속평균).shp  POINT (207534.143 552671.138)
# 171  0.0  1.5  2.3  ...  553780.275  01(풍속평균).shp  POINT (207851.075 553780.275)
# 205  1.6  1.9  2.3  ...  552671.138  01(풍속평균).shp  POINT (207534.143 552671.138)
# 222  1.0  1.4  2.5  ...  553780.275  01(풍속평균).shp  POINT (207851.075 553780.275)
# 254  1.4  1.6  1.8  ...  552671.138  01(풍속평균).shp  POINT (207534.143 552671.138)
# 271  1.7  2.0  2.2  ...  553780.275  01(풍속평균).shp  POINT (207851.075 553780.275)
# 312  1.7  1.8  1.9  ...  552671.138  01(풍속평균).shp  POINT (207534.143 552671.138)
# ...

# %%
#중랑구 월별 평균 리스트
wind_jr_avg = []

# %% [markdown]
# ## 1월

# %%
wind_jr_01 = wind_jr['M01']
wind_jr_01_list = wind_jr_01.tolist()

res = 0
for i in wind_jr_01_list:
  res+=i

avg_jr_01 = round(res/(len(wind_jr_01_list)),2)
wind_jr_avg.append(avg_jr_01)

# %% [markdown]
# ## 2월

# %%
wind_jr_02 = wind_jr['M02']
wind_jr_02_list = wind_jr_02.tolist()

res = 0
for i in wind_jr_02_list:
  res+=i

avg_jr_02 = round(res/(len(wind_jr_02_list)),2)
wind_jr_avg.append(avg_jr_02)

# %% [markdown]
# ## 3월

# %%
wind_jr_03 = wind_jr['M03']
wind_jr_03_list = wind_jr_03.tolist()

res = 0
for i in wind_jr_03_list:
  res+=i

avg_jr_03 = round(res/(len(wind_jr_03_list)),2)
wind_jr_avg.append(avg_jr_03)

# %% [markdown]
# ## 4월

# %%
wind_jr_04 = wind_jr['M04']
wind_jr_04_list = wind_jr_04.tolist()

res = 0
for i in wind_jr_04_list:
  res+=i

avg_jr_04 = round(res/(len(wind_jr_04_list)),2)
wind_jr_avg.append(avg_jr_04)

# %% [markdown]
# ## 5월

# %%
wind_jr_05 = wind_jr['M05']
wind_jr_05_list = wind_jr_05.tolist()

res = 0
for i in wind_jr_05_list:
  res+=i

avg_jr_05 = round(res/(len(wind_jr_05_list)),2)
wind_jr_avg.append(avg_jr_05)

# %% [markdown]
# ## 6월

# %%
wind_jr_06 = wind_jr['M06']
wind_jr_06_list = wind_jr_06.tolist()

res = 0
for i in wind_jr_06_list:
  res+=i

avg_jr_06 = round(res/(len(wind_jr_06_list)),2)
wind_jr_avg.append(avg_jr_06)

# %% [markdown]
# ## 7월

# %%
wind_jr_07 = wind_jr['M07']
wind_jr_07_list = wind_jr_07.tolist()

res = 0
for i in wind_jr_07_list:
  res+=i

avg_jr_07 = round(res/(len(wind_jr_07_list)),2)
wind_jr_avg.append(avg_jr_07)

# %% [markdown]
# ## 8월

# %%
wind_jr_08 = wind_jr['M08']
wind_jr_08_list = wind_jr_08.tolist()

res = 0
for i in wind_jr_08_list:
  res+=i

avg_jr_08 = round(res/(len(wind_jr_08_list)),2)
wind_jr_avg.append(avg_jr_08)

# %% [markdown]
# ## 9월

# %%
wind_jr_09 = wind_jr['M09']
wind_jr_09_list = wind_jr_09.tolist()

res = 0
for i in wind_jr_09_list:
  res+=i

avg_jr_09 = round(res/(len(wind_jr_09_list)),2)
wind_jr_avg.append(avg_jr_09)

# %% [markdown]
# ## 10월

# %%
wind_jr_10 = wind_jr['M10']
wind_jr_10_list = wind_jr_10.tolist()

res = 0
for i in wind_jr_10_list:
  res+=i

avg_jr_10 = round(res/(len(wind_jr_10_list)),2)
wind_jr_avg.append(avg_jr_10)

# %% [markdown]
# ## 11월

# %%
wind_jr_11 = wind_jr['M11']
wind_jr_11_list = wind_jr_11.tolist()

res = 0
for i in wind_jr_11_list:
  res+=i

avg_jr_11 = round(res/(len(wind_jr_11_list)),2)
wind_jr_avg.append(avg_jr_11)

# %% [markdown]
# ## 12월

# %%
wind_jr_12 = wind_jr['M12']
wind_jr_12_list = wind_jr_12.tolist()

res = 0
for i in wind_jr_12_list:
  res+=i

avg_jr_12 = round(res/(len(wind_jr_12_list)),2)
wind_jr_avg.append(avg_jr_12)

# %%
print("중랑구 1월~12월 평균 풍속: {}".format(wind_jr_avg))
# Out:
# 중랑구 1월~12월 평균 풍속: [1.45, 1.84, 2.18, 2.23, 2.19, 2.04, 2.16, 2.06, 1.83, 1.76, 1.86, 1.56]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_jr_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('중랑구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 동대문구

# %%
wind_dd = wind[wind["ADDR_KOR"].str.contains('동대문구')]
wind_dd
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 18   0.9  1.7  2.1  ...  554394.772  01(풍속평균).shp  POINT (206164.021 554394.772)
# 49   1.6  1.5  2.3  ...  553078.895  01(풍속평균).shp  POINT (204425.265 553078.895)
# 69   1.8  2.0  2.4  ...  554394.772  01(풍속평균).shp  POINT (206164.021 554394.772)
# 108  1.7  1.9  2.3  ...  553078.895  01(풍속평균).shp  POINT (204425.265 553078.895)
# 128  1.8  1.9  2.1  ...  554394.772  01(풍속평균).shp  POINT (206164.021 554394.772)
# 138  1.8  1.9  2.2  ...  554394.772  01(풍속평균).shp  POINT (206164.021 554394.772)
# 170  0.0  1.4  1.9  ...  553078.895  01(풍속평균).shp  POINT (204425.265 553078.895)
# 189  1.8  1.9  2.4  ...  554394.772  01(풍속평균).shp  POINT (206164.021 554394.772)
# 221  1.3  1.5  1.8  ...  553078.895  01(풍속평균).shp  POINT (204425.265 553078.895)
# 238  1.8  2.0  2.1  ...  554394.772  01(풍속평균).shp  POINT (206164.021 554394.772)
# 270  1.7  1.8  2.0  ...  553078.895  01(풍속평균).shp  POINT (204425.265 553078.895)
# ...

# %%
#동대문구 월별 평균 리스트
wind_dd_avg = []

# %% [markdown]
# ## 1월

# %%
wind_dd_01 = wind_dd['M01']
wind_dd_01_list = wind_dd_01.tolist()

res = 0
for i in wind_dd_01_list:
  res+=i

avg_dd_01 = round(res/(len(wind_dd_01_list)),2)
wind_dd_avg.append(avg_dd_01)

# %% [markdown]
# ## 2월

# %%
wind_dd_02 = wind_dd['M02']
wind_dd_02_list = wind_dd_02.tolist()

res = 0
for i in wind_dd_02_list:
  res+=i

avg_dd_02 = round(res/(len(wind_dd_02_list)),2)
wind_dd_avg.append(avg_dd_02)

# %% [markdown]
# ## 3월

# %%
wind_dd_03 = wind_dd['M03']
wind_dd_03_list = wind_dd_03.tolist()

res = 0
for i in wind_dd_03_list:
  res+=i

avg_dd_03 = round(res/(len(wind_dd_03_list)),2)
wind_dd_avg.append(avg_dd_03)

# %% [markdown]
# ## 4월

# %%
wind_dd_04 = wind_dd['M04']
wind_dd_04_list = wind_dd_04.tolist()

res = 0
for i in wind_dd_04_list:
  res+=i

avg_dd_04 = round(res/(len(wind_dd_04_list)),2)
wind_dd_avg.append(avg_dd_04)

# %% [markdown]
# ## 5월

# %%
wind_dd_05 = wind_dd['M05']
wind_dd_05_list = wind_dd_05.tolist()

res = 0
for i in wind_dd_05_list:
  res+=i

avg_dd_05 = round(res/(len(wind_dd_05_list)),2)
wind_dd_avg.append(avg_dd_05)

# %% [markdown]
# ## 6월

# %%
wind_dd_06 = wind_dd['M06']
wind_dd_06_list = wind_dd_06.tolist()

res = 0
for i in wind_dd_06_list:
  res+=i

avg_dd_06 = round(res/(len(wind_dd_06_list)),2)
wind_dd_avg.append(avg_dd_06)

# %% [markdown]
# ## 7월

# %%
wind_dd_07 = wind_dd['M07']
wind_dd_07_list = wind_dd_07.tolist()

res = 0
for i in wind_dd_07_list:
  res+=i

avg_dd_07 = round(res/(len(wind_dd_07_list)),2)
wind_dd_avg.append(avg_dd_07)

# %% [markdown]
# ## 8월

# %%
wind_dd_08 = wind_dd['M08']
wind_dd_08_list = wind_dd_08.tolist()

res = 0
for i in wind_dd_08_list:
  res+=i

avg_dd_08 = round(res/(len(wind_dd_08_list)),2)
wind_dd_avg.append(avg_dd_08)

# %% [markdown]
# ## 9월

# %%
wind_dd_09 = wind_dd['M09']
wind_dd_09_list = wind_dd_09.tolist()

res = 0
for i in wind_dd_09_list:
  res+=i

avg_dd_09 = round(res/(len(wind_dd_09_list)),2)
wind_dd_avg.append(avg_dd_09)

# %% [markdown]
# ## 10월

# %%
wind_dd_10 = wind_dd['M10']
wind_dd_10_list = wind_dd_10.tolist()

res = 0
for i in wind_dd_10_list:
  res+=i

avg_dd_10 = round(res/(len(wind_dd_10_list)),2)
wind_dd_avg.append(avg_dd_10)

# %% [markdown]
# ## 11월

# %%
wind_dd_11 = wind_dd['M11']
wind_dd_11_list = wind_dd_11.tolist()

res = 0
for i in wind_dd_11_list:
  res+=i

avg_dd_11 = round(res/(len(wind_dd_11_list)),2)
wind_dd_avg.append(avg_dd_11)

# %% [markdown]
# ## 12월

# %%
wind_dd_12 = wind_dd['M12']
wind_dd_12_list = wind_dd_12.tolist()

res = 0
for i in wind_dd_12_list:
  res+=i

avg_dd_12 = round(res/(len(wind_dd_12_list)),2)
wind_dd_avg.append(avg_dd_12)

# %%
print("동대문구 1월~12월 평균 풍속: {}".format(wind_dd_avg))
# Out:
# 동대문구 1월~12월 평균 풍속: [1.5, 1.81, 2.09, 2.06, 1.91, 1.82, 1.68, 1.71, 1.59, 1.56, 1.68, 1.46]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_dd_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('동대문구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 광진구

# %%
wind_gw = wind[wind["ADDR_KOR"].str.contains('광진구')]
wind_gw
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 29   1.8  2.1  2.3  ...  550469.139  01(풍속평균).shp  POINT (207139.050 550469.139)
# 54   2.2  1.8  2.8  ...  548718.981  01(풍속평균).shp  POINT (206990.325 548718.981)
# 80   1.7  1.8  2.3  ...  550469.139  01(풍속평균).shp  POINT (207139.050 550469.139)
# 113  1.7  2.0  2.2  ...  548718.981  01(풍속평균).shp  POINT (206990.325 548718.981)
# 149  1.7  1.8  2.1  ...  550469.139  01(풍속평균).shp  POINT (207139.050 550469.139)
# 174  0.0  1.8  2.5  ...  548718.981  01(풍속평균).shp  POINT (206990.325 548718.981)
# 200  1.6  1.8  2.3  ...  550469.139  01(풍속평균).shp  POINT (207139.050 550469.139)
# 226  2.0  2.1  2.6  ...  548718.981  01(풍속평균).shp  POINT (206990.325 548718.981)
# 249  1.4  1.8  1.8  ...  550469.139  01(풍속평균).shp  POINT (207139.050 550469.139)
# 275  1.7  1.8  2.0  ...  548718.981  01(풍속평균).shp  POINT (206990.325 548718.981)
# 303  1.7  1.8  1.7  ...  550469.139  01(풍속평균).shp  POINT (207139.050 550469.139)
# ...

# %%
#광진구 월별 평균 리스트
wind_gw_avg = []

# %% [markdown]
# ## 1월

# %%
wind_gw_01 = wind_gw['M01']
wind_gw_01_list = wind_gw_01.tolist()

res = 0
for i in wind_gw_01_list:
  res+=i

avg_gw_01 = round(res/(len(wind_gw_01_list)),2)
wind_gw_avg.append(avg_gw_01)

# %% [markdown]
# ## 2월

# %%
wind_gw_02 = wind_gw['M02']
wind_gw_02_list = wind_gw_02.tolist()

res = 0
for i in wind_gw_02_list:
  res+=i

avg_gw_02 = round(res/(len(wind_gw_02_list)),2)
wind_gw_avg.append(avg_gw_02)

# %% [markdown]
# ## 3월

# %%
wind_gw_03 = wind_gw['M03']
wind_gw_03_list = wind_gw_03.tolist()

res = 0
for i in wind_gw_03_list:
  res+=i

avg_gw_03 = round(res/(len(wind_gw_03_list)),2)
wind_gw_avg.append(avg_gw_03)

# %% [markdown]
# ## 4월

# %%
wind_gw_04 = wind_gw['M04']
wind_gw_04_list = wind_gw_04.tolist()

res = 0
for i in wind_gw_04_list:
  res+=i

avg_gw_04 = round(res/(len(wind_gw_04_list)),2)
wind_gw_avg.append(avg_gw_04)

# %% [markdown]
# ## 5월

# %%
wind_gw_05 = wind_gw['M05']
wind_gw_05_list = wind_gw_05.tolist()

res = 0
for i in wind_gw_05_list:
  res+=i

avg_gw_05 = round(res/(len(wind_gw_05_list)),2)
wind_gw_avg.append(avg_gw_05)

# %% [markdown]
# ## 6월

# %%
wind_gw_06 = wind_gw['M06']
wind_gw_06_list = wind_gw_06.tolist()

res = 0
for i in wind_gw_06_list:
  res+=i

avg_gw_06 = round(res/(len(wind_gw_06_list)),2)
wind_gw_avg.append(avg_gw_06)

# %% [markdown]
# ## 7월

# %%
wind_gw_07 = wind_gw['M07']
wind_gw_07_list = wind_gw_07.tolist()

res = 0
for i in wind_gw_07_list:
  res+=i

avg_gw_07 = round(res/(len(wind_gw_07_list)),2)
wind_gw_avg.append(avg_gw_07)

# %% [markdown]
# ## 8월

# %%
wind_gw_08= wind_gw['M08']
wind_gw_08_list = wind_gw_08.tolist()

res = 0
for i in wind_gw_08_list:
  res+=i

avg_gw_08 = round(res/(len(wind_gw_08_list)),2)
wind_gw_avg.append(avg_gw_08)

# %% [markdown]
# ## 9월

# %%
wind_gw_09 = wind_gw['M09']
wind_gw_09_list = wind_gw_09.tolist()

res = 0
for i in wind_gw_09_list:
  res+=i

avg_gw_09 = round(res/(len(wind_gw_09_list)),2)
wind_gw_avg.append(avg_gw_09)

# %% [markdown]
# ## 10월

# %%
wind_gw_10 = wind_gw['M10']
wind_gw_10_list = wind_gw_10.tolist()

res = 0
for i in wind_gw_10_list:
  res+=i

avg_gw_10 = round(res/(len(wind_gw_10_list)),2)
wind_gw_avg.append(avg_gw_10)

# %% [markdown]
# ## 11월

# %%
wind_gw_11 = wind_gw['M11']
wind_gw_11_list = wind_gw_11.tolist()

res = 0
for i in wind_gw_11_list:
  res+=i

avg_gw_11 = round(res/(len(wind_gw_11_list)),2)
wind_gw_avg.append(avg_gw_11)

# %% [markdown]
# ## 12월

# %%
wind_gw_12 = wind_gw['M12']
wind_gw_12_list = wind_gw_12.tolist()

res = 0
for i in wind_gw_12_list:
  res+=i

avg_gw_12 = round(res/(len(wind_gw_12_list)),2)
wind_gw_avg.append(avg_gw_12)

# %%
print("광진구 1월~12월 평균 풍속: {}".format(wind_gw_avg))
# Out:
# 광진구 1월~12월 평균 풍속: [1.58, 1.83, 2.08, 1.97, 1.84, 1.74, 1.69, 1.73, 1.59, 1.51, 1.67, 1.48]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_gw_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('광진구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 성동구

# %%
wind_sd = wind[wind["ADDR_KOR"].str.contains('성동구')]
wind_sd
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 10   1.8  2.0  2.4  ...  549504.437  01(풍속평균).shp  POINT (203587.734 549504.437)
# 33   2.2  2.4  2.7  ...  548835.849  01(풍속평균).shp  POINT (203685.228 548835.849)
# 62   2.1  1.8  2.7  ...  549504.437  01(풍속평균).shp  POINT (203587.734 549504.437)
# 84   2.0  2.2  2.7  ...  548835.849  01(풍속평균).shp  POINT (203685.228 548835.849)
# 121  2.0  2.2  2.7  ...  549504.437  01(풍속평균).shp  POINT (203587.734 549504.437)
# 153  0.0  2.0  2.5  ...  548835.849  01(풍속평균).shp  POINT (203685.228 548835.849)
# 182  0.0  2.6  3.8  ...  549504.437  01(풍속평균).shp  POINT (203587.734 549504.437)
# 204  1.9  2.1  2.5  ...  548835.849  01(풍속평균).shp  POINT (203685.228 548835.849)
# 230  1.8  2.0  2.4  ...  549504.437  01(풍속평균).shp  POINT (203587.734 549504.437)
# 253  1.8  2.0  2.1  ...  548835.849  01(풍속평균).shp  POINT (203685.228 548835.849)
# 283  2.0  2.2  2.4  ...  549504.437  01(풍속평균).shp  POINT (203587.734 549504.437)
# ...

# %%
#성동구 월별 평균 리스트
wind_sd_avg = []

# %% [markdown]
# ## 1월

# %%
wind_sd_01 = wind_sd['M01']
wind_sd_01_list = wind_sd_01.tolist()

res = 0
for i in wind_sd_01_list:
  res+=i

avg_sd_01 = round(res/(len(wind_sd_01_list)),2)
wind_sd_avg.append(avg_sd_01)

# %% [markdown]
# ## 2월

# %%
wind_sd_02 = wind_sd['M02']
wind_sd_02_list = wind_sd_02.tolist()

res = 0
for i in wind_sd_02_list:
  res+=i

avg_sd_02 = round(res/(len(wind_sd_02_list)),2)
wind_sd_avg.append(avg_sd_02)

# %% [markdown]
# ## 3월

# %%
wind_sd_03 = wind_sd['M03']
wind_sd_03_list = wind_sd_03.tolist()

res = 0
for i in wind_sd_03_list:
  res+=i

avg_sd_03 = round(res/(len(wind_sd_03_list)),2)
wind_sd_avg.append(avg_sd_03)

# %% [markdown]
# ## 4월

# %%
wind_sd_04 = wind_sd['M04']
wind_sd_04_list = wind_sd_04.tolist()

res = 0
for i in wind_sd_04_list:
  res+=i

avg_sd_04 = round(res/(len(wind_sd_04_list)),2)
wind_sd_avg.append(avg_sd_04)

# %% [markdown]
# ## 5월

# %%
wind_sd_05 = wind_sd['M05']
wind_sd_05_list = wind_sd_05.tolist()

res = 0
for i in wind_sd_05_list:
  res+=i

avg_sd_05 = round(res/(len(wind_sd_05_list)),2)
wind_sd_avg.append(avg_sd_05)

# %% [markdown]
# ## 6월

# %%
wind_sd_06 = wind_sd['M06']
wind_sd_06_list = wind_sd_06.tolist()

res = 0
for i in wind_sd_06_list:
  res+=i

avg_sd_06 = round(res/(len(wind_sd_06_list)),2)
wind_sd_avg.append(avg_sd_06)

# %% [markdown]
# ## 7월

# %%
wind_sd_07 = wind_sd['M07']
wind_sd_07_list = wind_sd_07.tolist()

res = 0
for i in wind_sd_07_list:
  res+=i

avg_sd_07 = round(res/(len(wind_sd_07_list)),2)
wind_sd_avg.append(avg_sd_07)

# %% [markdown]
# ## 8월

# %%
wind_sd_08 = wind_sd['M08']
wind_sd_08_list = wind_sd_08.tolist()

res = 0
for i in wind_sd_08_list:
  res+=i

avg_sd_08 = round(res/(len(wind_sd_08_list)),2)
wind_sd_avg.append(avg_sd_08)

# %% [markdown]
# ## 9월

# %%
wind_sd_09 = wind_sd['M09']
wind_sd_09_list = wind_sd_09.tolist()

res = 0
for i in wind_sd_09_list:
  res+=i

avg_sd_09 = round(res/(len(wind_sd_09_list)),2)
wind_sd_avg.append(avg_sd_09)

# %% [markdown]
# ## 10월

# %%
wind_sd_10 = wind_sd['M10']
wind_sd_10_list = wind_sd_10.tolist()

res = 0
for i in wind_sd_10_list:
  res+=i

avg_sd_10 = round(res/(len(wind_sd_10_list)),2)
wind_sd_avg.append(avg_sd_10)

# %% [markdown]
# ## 11월

# %%
wind_sd_11 = wind_sd['M11']
wind_sd_11_list = wind_sd_11.tolist()

res = 0
for i in wind_sd_11_list:
  res+=i

avg_sd_11 = round(res/(len(wind_sd_11_list)),2)
wind_sd_avg.append(avg_sd_11)

# %% [markdown]
# ## 12월

# %%
wind_sd_12 = wind_sd['M12']
wind_sd_12_list = wind_sd_12.tolist()

res = 0
for i in wind_sd_12_list:
  res+=i

avg_sd_12 = round(res/(len(wind_sd_12_list)),2)
wind_sd_avg.append(avg_sd_12)

# %%
print("성동구 1월~12월 평균 풍속: {}".format(wind_sd_avg))
# Out:
# 성동구 1월~12월 평균 풍속: [1.71, 2.11, 2.44, 2.42, 2.27, 2.11, 2.06, 1.97, 1.81, 1.78, 1.95, 1.74]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_sd_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('성동구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 용산구

# %%
wind_ys = wind[wind["ADDR_KOR"].str.contains('용산구')]
wind_ys
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 32   1.8  2.3  2.2  ...  549612.281  01(풍속평균).shp  POINT (197366.853 549612.281)
# 56   1.5  1.5  2.1  ...  546374.692  01(풍속평균).shp  POINT (198011.111 546374.692)
# 83   1.7  1.8  2.3  ...  549612.281  01(풍속평균).shp  POINT (197366.853 549612.281)
# 115  1.4  1.5  2.2  ...  546374.692  01(풍속평균).shp  POINT (198011.111 546374.692)
# 152  0.0  1.6  2.1  ...  549612.281  01(풍속평균).shp  POINT (197366.853 549612.281)
# 176  0.0  1.4  2.1  ...  546374.692  01(풍속평균).shp  POINT (198011.111 546374.692)
# 203  1.5  1.6  2.2  ...  549612.281  01(풍속평균).shp  POINT (197366.853 549612.281)
# 228  1.6  1.7  2.3  ...  546374.692  01(풍속평균).shp  POINT (198011.111 546374.692)
# 252  1.6  1.8  1.9  ...  549612.281  01(풍속평균).shp  POINT (197366.853 549612.281)
# 277  1.5  1.7  1.8  ...  546374.692  01(풍속평균).shp  POINT (198011.111 546374.692)
# 310  1.7  1.8  1.7  ...  549612.281  01(풍속평균).shp  POINT (197366.853 549612.281)
# ...

# %%
#용산구 월별 평균 리스트
wind_ys_avg = []

# %% [markdown]
# ## 1월

# %%
wind_ys_01 = wind_ys['M01']
wind_ys_01_list = wind_ys_01.tolist()

res = 0
for i in wind_ys_01_list:
  res+=i

avg_ys_01 = round(res/(len(wind_ys_01_list)),2)
wind_ys_avg.append(avg_ys_01)

# %% [markdown]
# ## 2월

# %%
wind_ys_02 = wind_ys['M02']
wind_ys_02_list = wind_ys_02.tolist()

res = 0
for i in wind_ys_02_list:
  res+=i

avg_ys_02 = round(res/(len(wind_ys_02_list)),2)
wind_ys_avg.append(avg_ys_02)

# %% [markdown]
# ## 3월

# %%
wind_ys_03 = wind_ys['M03']
wind_ys_03_list = wind_ys_03.tolist()

res = 0
for i in wind_ys_03_list:
  res+=i

avg_ys_03 = round(res/(len(wind_ys_03_list)),2)
wind_ys_avg.append(avg_ys_03)

# %% [markdown]
# ## 4월

# %%
wind_ys_04 = wind_ys['M04']
wind_ys_04_list = wind_ys_04.tolist()

res = 0
for i in wind_ys_04_list:
  res+=i

avg_ys_04 = round(res/(len(wind_ys_04_list)),2)
wind_ys_avg.append(avg_ys_04)

# %% [markdown]
# ## 5월

# %%
wind_ys_05 = wind_ys['M05']
wind_ys_05_list = wind_ys_05.tolist()

res = 0
for i in wind_ys_05_list:
  res+=i

avg_ys_05 = round(res/(len(wind_ys_05_list)),2)
wind_ys_avg.append(avg_ys_05)

# %% [markdown]
# ## 6월

# %%
wind_ys_06 = wind_ys['M06']
wind_ys_06_list = wind_ys_06.tolist()

res = 0
for i in wind_ys_06_list:
  res+=i

avg_ys_06 = round(res/(len(wind_ys_06_list)),2)
wind_ys_avg.append(avg_ys_06)

# %% [markdown]
# ## 7월

# %%
wind_ys_07 = wind_ys['M07']
wind_ys_07_list = wind_ys_07.tolist()

res = 0
for i in wind_ys_07_list:
  res+=i

avg_ys_07 = round(res/(len(wind_ys_07_list)),2)
wind_ys_avg.append(avg_ys_07)

# %% [markdown]
# ## 8월

# %%
wind_ys_08 = wind_ys['M08']
wind_ys_08_list = wind_ys_08.tolist()

res = 0
for i in wind_ys_08_list:
  res+=i

avg_ys_08 = round(res/(len(wind_ys_08_list)),2)
wind_ys_avg.append(avg_ys_08)

# %% [markdown]
# ## 9월

# %%
wind_ys_09 = wind_ys['M09']
wind_ys_09_list = wind_ys_09.tolist()

res = 0
for i in wind_ys_09_list:
  res+=i

avg_ys_09 = round(res/(len(wind_ys_09_list)),2)
wind_ys_avg.append(avg_ys_09)

# %% [markdown]
# ## 10월

# %%
wind_ys_10 = wind_ys['M10']
wind_ys_10_list = wind_ys_10.tolist()

res = 0
for i in wind_ys_10_list:
  res+=i

avg_ys_10 = round(res/(len(wind_ys_10_list)),2)
wind_ys_avg.append(avg_ys_10)

# %% [markdown]
# ## 11월

# %%
wind_ys_11 = wind_ys['M11']
wind_ys_11_list = wind_ys_11.tolist()

res = 0
for i in wind_ys_11_list:
  res+=i

avg_ys_11 = round(res/(len(wind_ys_11_list)),2)
wind_ys_avg.append(avg_ys_11)

# %% [markdown]
# ## 12월

# %%
wind_ys_12 = wind_ys['M12']
wind_ys_12_list = wind_ys_12.tolist()

res = 0
for i in wind_ys_12_list:
  res+=i

avg_ys_12 = round(res/(len(wind_ys_12_list)),2)
wind_ys_avg.append(avg_ys_12)

# %%
print("용산구 1월~12월 평균 풍속: {}".format(wind_ys_avg))
# Out:
# 용산구 1월~12월 평균 풍속: [1.38, 1.71, 1.97, 2.01, 1.96, 1.85, 1.92, 1.88, 1.67, 1.53, 1.67, 1.44]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_ys_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('용산구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 중구

# %%
wind_j = wind[wind["ADDR_KOR"].str.contains('중구')]
wind_j
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 8    2.5  2.3  2.7  ...  550447.354  01(풍속평균).shp  POINT (198798.171 550447.354)
# 17   1.6  1.7  1.8  ...  550710.248  01(풍속평균).shp  POINT (199302.289 550710.248)
# 35   1.9  2.0  2.3  ...  550432.474  01(풍속평균).shp  POINT (200264.810 550432.474)
# 60   2.5  2.1  2.2  ...  550447.354  01(풍속평균).shp  POINT (198798.171 550447.354)
# 68   1.5  1.6  2.1  ...  550710.248  01(풍속평균).shp  POINT (199302.289 550710.248)
# 86   1.7  1.9  2.2  ...  550432.474  01(풍속평균).shp  POINT (200264.810 550432.474)
# 119  2.3  2.5  2.6  ...  550447.354  01(풍속평균).shp  POINT (198798.171 550447.354)
# 127  1.6  1.6  1.8  ...  550710.248  01(풍속평균).shp  POINT (199302.289 550710.248)
# 137  1.7  1.6  1.9  ...  550710.248  01(풍속평균).shp  POINT (199302.289 550710.248)
# 155  0.0  1.7  2.2  ...  550432.474  01(풍속평균).shp  POINT (200264.810 550432.474)
# 180  0.0  1.8  2.6  ...  550447.354  01(풍속평균).shp  POINT (198798.171 550447.354)
# ...

# %%
#중구 월별 평균 리스트
wind_j_avg = []

# %% [markdown]
# ## 1월

# %%
wind_j_01 = wind_j['M01']
wind_j_01_list = wind_j_01.tolist()

res = 0
for i in wind_j_01_list:
  res+=i

avg_j_01 = round(res/(len(wind_j_01_list)),2)
wind_j_avg.append(avg_j_01)

# %% [markdown]
# ## 2월

# %%
wind_j_02 = wind_j['M02']
wind_j_02_list = wind_j_02.tolist()

res = 0
for i in wind_j_02_list:
  res+=i

avg_j_02 = round(res/(len(wind_j_02_list)),2)
wind_j_avg.append(avg_j_02)

# %% [markdown]
# ## 3월

# %%
wind_j_03 = wind_j['M03']
wind_j_03_list = wind_j_03.tolist()

res = 0
for i in wind_j_03_list:
  res+=i

avg_j_03 = round(res/(len(wind_j_03_list)),2)
wind_j_avg.append(avg_j_03)

# %% [markdown]
# ## 4월

# %%
wind_j_04 = wind_j['M04']
wind_j_04_list = wind_j_04.tolist()

res = 0
for i in wind_j_04_list:
  res+=i

avg_j_04 = round(res/(len(wind_j_04_list)),2)
wind_j_avg.append(avg_j_04)

# %% [markdown]
# ## 5월

# %%
wind_j_05 = wind_j['M05']
wind_j_05_list = wind_j_05.tolist()

res = 0
for i in wind_j_05_list:
  res+=i

avg_j_05 = round(res/(len(wind_j_05_list)),2)
wind_j_avg.append(avg_j_05)

# %% [markdown]
# ## 6월

# %%
wind_j_06 = wind_j['M06']
wind_j_06_list = wind_j_06.tolist()

res = 0
for i in wind_j_06_list:
  res+=i

avg_j_06 = round(res/(len(wind_j_06_list)),2)
wind_j_avg.append(avg_j_06)

# %% [markdown]
# ## 7월

# %%
wind_j_07 = wind_j['M07']
wind_j_07_list = wind_j_07.tolist()

res = 0
for i in wind_j_07_list:
  res+=i

avg_j_07 = round(res/(len(wind_j_07_list)),2)
wind_j_avg.append(avg_j_07)

# %% [markdown]
# ## 8월

# %%
wind_j_08 = wind_j['M08']
wind_j_08_list = wind_j_08.tolist()

res = 0
for i in wind_j_08_list:
  res+=i

avg_j_08 = round(res/(len(wind_j_08_list)),2)
wind_j_avg.append(avg_j_08)

# %% [markdown]
# ## 9월

# %%
wind_j_09 = wind_j['M09']
wind_j_09_list = wind_j_09.tolist()

res = 0
for i in wind_j_09_list:
  res+=i

avg_j_09= round(res/(len(wind_j_09_list)),2)
wind_j_avg.append(avg_j_09)

# %% [markdown]
# ## 10월

# %%
wind_j_10 = wind_j['M10']
wind_j_10_list = wind_j_10.tolist()

res = 0
for i in wind_j_10_list:
  res+=i

avg_j_10 = round(res/(len(wind_j_10_list)),2)
wind_j_avg.append(avg_j_10)

# %% [markdown]
# ## 11월

# %%
wind_j_11 = wind_j['M11']
wind_j_11_list = wind_j_11.tolist()

res = 0
for i in wind_j_11_list:
  res+=i

avg_j_11 = round(res/(len(wind_j_11_list)),2)
wind_j_avg.append(avg_j_11)

# %% [markdown]
# ## 12월

# %%
wind_j_12 = wind_j['M12']
wind_j_12_list = wind_j_12.tolist()

res = 0
for i in wind_j_12_list:
  res+=i

avg_j_12 = round(res/(len(wind_j_12_list)),2)
wind_j_avg.append(avg_j_12)

# %%
print("중구 1월~12월 평균 풍속: {}".format(wind_j_avg))
# Out:
# 중구 1월~12월 평균 풍속: [1.7, 1.91, 2.05, 1.94, 1.58, 1.48, 1.4, 1.56, 1.59, 1.61, 1.82, 1.7]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_j_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('중구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # 종로구

# %%
wind_jongro = wind[wind["ADDR_KOR"].str.contains('종로구')]
wind_jongro
# Out:
#      M01  M02  M03  ...     CMDT_NM     SOURCETHM                       geometry
# 9    0.0  0.0  0.0  ...  557329.023  01(풍속평균).shp  POINT (196159.640 557329.023)
# 36   1.5  1.5  1.7  ...  552350.259  01(풍속평균).shp  POINT (199028.108 552350.259)
# 41   2.8  2.6  3.4  ...  552433.066  01(풍속평균).shp  POINT (196961.427 552433.066)
# 61   0.0  0.0  0.0  ...  557329.023  01(풍속평균).shp  POINT (196159.640 557329.023)
# 87   1.3  1.5  1.6  ...  552350.259  01(풍속평균).shp  POINT (199028.108 552350.259)
# 93   2.5  2.9  3.5  ...  552433.066  01(풍속평균).shp  POINT (196961.427 552433.066)
# 120  2.0  2.3  2.8  ...  557329.023  01(풍속평균).shp  POINT (196159.640 557329.023)
# 156  0.0  1.5  1.7  ...  552350.259  01(풍속평균).shp  POINT (199028.108 552350.259)
# 161  0.0  2.2  3.1  ...  552433.066  01(풍속평균).shp  POINT (196961.427 552433.066)
# 181  0.0  0.0  0.0  ...  557329.023  01(풍속평균).shp  POINT (196159.640 557329.023)
# 207  1.3  1.3  1.5  ...  552350.259  01(풍속평균).shp  POINT (199028.108 552350.259)
# ...

# %%
#종로구 월별 평균 리스트
wind_jongro_avg = []

# %% [markdown]
# ## 1월

# %%
wind_jongro_01 = wind_jongro['M01']
wind_jongro_01_list = wind_jongro_01.tolist()

res = 0
for i in wind_jongro_01_list:
  res+=i

avg_jongro_01 = round(res/(len(wind_jongro_01_list)),2)
wind_jongro_avg.append(avg_jongro_01)

# %% [markdown]
# ## 2월

# %%
wind_jongro_02 = wind_jongro['M02']
wind_jongro_02_list = wind_jongro_02.tolist()

res = 0
for i in wind_jongro_02_list:
  res+=i

avg_jongro_02 = round(res/(len(wind_jongro_02_list)),2)
wind_jongro_avg.append(avg_jongro_02)

# %% [markdown]
# ## 3월

# %%
wind_jongro_03 = wind_jongro['M03']
wind_jongro_03_list = wind_jongro_03.tolist()

res = 0
for i in wind_jongro_03_list:
  res+=i

avg_jongro_03 = round(res/(len(wind_jongro_03_list)),2)
wind_jongro_avg.append(avg_jongro_03)

# %% [markdown]
# ## 4월

# %%
wind_jongro_04 = wind_jongro['M04']
wind_jongro_04_list = wind_jongro_04.tolist()

res = 0
for i in wind_jongro_04_list:
  res+=i

avg_jongro_04 = round(res/(len(wind_jongro_04_list)),2)
wind_jongro_avg.append(avg_jongro_04)

# %% [markdown]
# ## 5월

# %%
wind_jongro_05 = wind_jongro['M05']
wind_jongro_05_list = wind_jongro_05.tolist()

res = 0
for i in wind_jongro_05_list:
  res+=i

avg_jongro_05 = round(res/(len(wind_jongro_05_list)),2)
wind_jongro_avg.append(avg_jongro_05)

# %% [markdown]
# ## 6월

# %%
wind_jongro_06 = wind_jongro['M06']
wind_jongro_06_list = wind_jongro_06.tolist()

res = 0
for i in wind_jongro_06_list:
  res+=i

avg_jongro_06 = round(res/(len(wind_jongro_06_list)),2)
wind_jongro_avg.append(avg_jongro_06)

# %% [markdown]
# ## 7월

# %%
wind_jongro_07 = wind_jongro['M07']
wind_jongro_07_list = wind_jongro_07.tolist()

res = 0
for i in wind_jongro_07_list:
  res+=i

avg_jongro_07 = round(res/(len(wind_jongro_07_list)),2)
wind_jongro_avg.append(avg_jongro_07)

# %% [markdown]
# ## 8월

# %%
wind_jongro_08 = wind_jongro['M08']
wind_jongro_08_list = wind_jongro_08.tolist()

res = 0
for i in wind_jongro_08_list:
  res+=i

avg_jongro_08 = round(res/(len(wind_jongro_08_list)),2)
wind_jongro_avg.append(avg_jongro_08)

# %% [markdown]
# ## 9월

# %%
wind_jongro_09 = wind_jongro['M09']
wind_jongro_09_list = wind_jongro_09.tolist()

res = 0
for i in wind_jongro_09_list:
  res+=i

avg_jongro_09 = round(res/(len(wind_jongro_09_list)),2)
wind_jongro_avg.append(avg_jongro_09)

# %% [markdown]
# ## 10월

# %%
wind_jongro_10 = wind_jongro['M10']
wind_jongro_10_list = wind_jongro_10.tolist()

res = 0
for i in wind_jongro_10_list:
  res+=i

avg_jongro_10 = round(res/(len(wind_jongro_10_list)),2)
wind_jongro_avg.append(avg_jongro_10)

# %% [markdown]
# ## 11월

# %%
wind_jongro_11 = wind_jongro['M11']
wind_jongro_11_list = wind_jongro_11.tolist()

res = 0
for i in wind_jongro_11_list:
  res+=i

avg_jongro_11 = round(res/(len(wind_jongro_11_list)),2)
wind_jongro_avg.append(avg_jongro_11)

# %% [markdown]
# ## 12월

# %%
wind_jongro_12 = wind_jongro['M12']
wind_jongro_12_list = wind_jongro_12.tolist()

res = 0
for i in wind_jongro_12_list:
  res+=i

avg_jongro_12 = round(res/(len(wind_jongro_12_list)),2)
wind_jongro_avg.append(avg_jongro_12)

# %%
print("종로구 1월~12월 평균 풍속: {}".format(wind_jongro_avg))
# Out:
# 종로구 1월~12월 평균 풍속: [1.57, 1.81, 1.98, 1.97, 1.83, 1.68, 1.66, 1.63, 1.55, 1.59, 1.77, 1.6]

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(line, wind_jongro_avg)
plt.xlabel('월')
plt.ylabel('풍속')
plt.title('종로구 2009~2017 월평균 풍속')
plt.ylim([0,2.5])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
