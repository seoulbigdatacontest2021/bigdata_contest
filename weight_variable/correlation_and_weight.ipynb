# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
plt.rc('font', family='NanumGothic')
matplotlib.rcParams['axes.unicode_minus'] = False

file = pd.read_csv('C:\\신현호\\2021_2학기_공모전\\코드구성\\상관관계분석\\구별_통합_데이터_02.csv',
                  encoding='utf-8')
file
# Out:
#       주소     코드  면적(km^2)     인구수평균  충전소 수  전기차 수  전기차 변수   전기사용량 평균  \
# 0   강동구   11250     24.59  467245.8     96   6154  0.0156  1523766.7
# 1   송파구   11240     33.87  673702.4    169  10646  0.0159  2663266.1
# 2    강남구  11230     39.50  566134.3    238  21296  0.0112  4660579.5
# 3    서초구  11220     46.98  443536.3    224  10242  0.0219  3389296.2
# 4    관악구  11210     29.57  530282.8     80   4131  0.0194  1272868.9
# 5    동작구  11200     16.35  413563.4     79   4424  0.0179  2644343.9
# 6   영등포구  11190     24.55  417110.5    131   7299  0.0179  1603282.2
# 7    금천구  11180     13.02  256755.4    101   2751  0.0367  1912756.7
# 8    구로구  11170     20.12  449120.4    132   5211  0.0253  2198200.4
# 9    강서구  11160     41.44  590933.4    191  10657  0.0179  1601101.6
# 10   양천구  11150     17.41  484655.3    113   5563  0.0203  2016054.3
# 11   마포구  11140     23.85  391897.6    140   5074  0.0276  1230442.6
# 12  서대문구  11130     17.63  324319.4     87   3517  0.0247  1354367.1
# 13   은평구  11120     29.71  497094.5    101   4465  0.0226  1525036.6
# 14   노원구  11110     35.44  574566.0    127   5066  0.0251   947581.1
# 15   도봉구  11100     20.65  352054.9     92   2665  0.0345  1693111.0
# 16   강북구  11090     23.60  333749.6     53   2118  0.0250   922579.4
# 17   성북구  11080     24.58  470969.2    120   4385  0.0274  1465512.6
# 18   중랑구  11070     18.50  416848.9    116   3055  0.0380  1107993.0
# 19  동대문구  11060     14.22  371200.4     82   3074  0.0267  1445114.0
# 20   광진구  11050     17.06  376045.2     73   3370  0.0217  1645551.9
# 21   성동구  11040     16.86  308862.9    129   4471  0.0289  1982030.6
# 22   용산구  11030     21.87  249509.1    113   3572  0.0316  1389768.6
# 23    중구  11020      9.96  137059.5     96   2740  0.0350  2531105.6
# 24  종로구   11010     23.91  166674.3     70   2172  0.0322  1739226.4
#
#     태양광 발전소 수     풍속 비율
# 0          12  0.059084
# 1          28  0.060867
# 2          11  0.062618
# 3          16  0.062401
# 4          13  0.063084
# 5          21  0.062840
# 6          28  0.063406
# 7          12  0.027710
# 8          19  0.029020
# 9          20  0.041260
# 10         30  0.028710
# 11         17  0.053820
# 12         14  0.040610
# 13         31  0.030030
# 14         14  0.031200
# 15         15  0.031050
# 16         28  0.033263
# 17         28  0.036507
# 18         16  0.025512
# 19         23  0.031034
# 20          8  0.027700
# 21          9  0.028740
# 22          4  0.034435
# 23          4  0.038784
# 24         21  0.045832

# %%
ppl = file['인구수평균']
charger = file['충전소 수']
car = file['전기차 수']
sol = file['태양광 발전소 수']
elec = file['전기사용량 평균']
ref_car = file['전기차 변수']
wind = file['풍속 비율']
df = pd.DataFrame()
df['인구수평균'] = ppl
df['충전소 수'] = charger
df['전기차 수'] = car
df['전기차 변수'] = ref_car
df['태양광 발전소 수'] = sol
df['전기사용량 평균'] = elec
df['풍력 비율'] = wind
df
# Out:
#        인구수평균  충전소 수  전기차 수  전기차 변수  태양광 발전소 수   전기사용량 평균     풍력 비율
# 0   467245.8     96   6154  0.0156         12  1523766.7  0.059084
# 1   673702.4    169  10646  0.0159         28  2663266.1  0.060867
# 2   566134.3    238  21296  0.0112         11  4660579.5  0.062618
# 3   443536.3    224  10242  0.0219         16  3389296.2  0.062401
# 4   530282.8     80   4131  0.0194         13  1272868.9  0.063084
# 5   413563.4     79   4424  0.0179         21  2644343.9  0.062840
# 6   417110.5    131   7299  0.0179         28  1603282.2  0.063406
# 7   256755.4    101   2751  0.0367         12  1912756.7  0.027710
# 8   449120.4    132   5211  0.0253         19  2198200.4  0.029020
# 9   590933.4    191  10657  0.0179         20  1601101.6  0.041260
# 10  484655.3    113   5563  0.0203         30  2016054.3  0.028710
# 11  391897.6    140   5074  0.0276         17  1230442.6  0.053820
# 12  324319.4     87   3517  0.0247         14  1354367.1  0.040610
# 13  497094.5    101   4465  0.0226         31  1525036.6  0.030030
# 14  574566.0    127   5066  0.0251         14   947581.1  0.031200
# 15  352054.9     92   2665  0.0345         15  1693111.0  0.031050
# 16  333749.6     53   2118  0.0250         28   922579.4  0.033263
# 17  470969.2    120   4385  0.0274         28  1465512.6  0.036507
# 18  416848.9    116   3055  0.0380         16  1107993.0  0.025512
# 19  371200.4     82   3074  0.0267         23  1445114.0  0.031034
# 20  376045.2     73   3370  0.0217          8  1645551.9  0.027700
# 21  308862.9    129   4471  0.0289          9  1982030.6  0.028740
# 22  249509.1    113   3572  0.0316          4  1389768.6  0.034435
# 23  137059.5     96   2740  0.0350          4  2531105.6  0.038784
# 24  166674.3     70   2172  0.0322         21  1739226.4  0.045832

# %%
# df['인구수평균'] = ppl
# df['충전소 수'] = charger
# df['전기차 수'] = car
# df['태양광 발전소 수'] = sol
# df['전기사용량 평균'] = elec

from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler(feature_range=(0,1))

ppl_scaled = min_max_scaler.fit_transform(df['인구수평균'].values.reshape(-1,1))
#charger_scaled = min_max_scaler.fit_transform(df['충전소 수'].values.reshape(-1,1))
#car_scaled = min_max_scaler.fit_transform(df['전기차 수'].values.reshape(-1,1))
ref_scaled = min_max_scaler.fit_transform(df['전기차 변수'].values.reshape(-1,1))
sol_scaled = min_max_scaler.fit_transform(df['태양광 발전소 수'].values.reshape(-1,1))
#elec_scaled = min_max_scaler.fit_transform(df['전기사용량 평균'].values.reshape(-1,1))
wind_scaled = min_max_scaler.fit_transform(df['풍력 비율'].values.reshape(-1,1))

scaled_df = pd.DataFrame()

scaled_df['인구수평균'] = np.array(ppl_scaled).flatten().tolist()
#scaled_df['충전소 수'] = np.array(charger_scaled).flatten().tolist()
#scaled_df['전기차 수'] = np.array(car_scaled).flatten().tolist()
scaled_df['전기차 변수'] = np.array(ref_scaled).flatten().tolist()
scaled_df['태양광 발전소 수'] = np.array(sol_scaled).flatten().tolist()
#scaled_df['전기사용량 평균'] = np.array(elec_scaled).flatten().tolist()
scaled_df['풍력 비율'] = np.array(wind_scaled).flatten().tolist()
scaled_df
# Out:
#        인구수평균    전기차 변수  태양광 발전소 수     풍력 비율
# 0   0.615281  0.164179   0.296296  0.885953
# 1   1.000000  0.175373   0.888889  0.933008
# 2   0.799554  0.000000   0.259259  0.979196
# 3   0.571100  0.399254   0.444444  0.973476
# 4   0.732747  0.305970   0.333333  0.991512
# 5   0.515247  0.250000   0.629630  0.985060
# 6   0.521857  0.250000   0.888889  1.000000
# 7   0.223046  0.951493   0.296296  0.058009
# 8   0.581506  0.526119   0.555556  0.092574
# 9   0.845765  0.250000   0.592593  0.415581
# 10  0.647723  0.339552   0.962963  0.084394
# 11  0.474875  0.611940   0.481481  0.747033
# 12  0.348947  0.503731   0.370370  0.398428
# 13  0.670902  0.425373   1.000000  0.119228
# 14  0.815266  0.518657   0.370370  0.150103
# 15  0.400630  0.869403   0.407407  0.146145
# 16  0.366520  0.514925   0.888889  0.204545
# 17  0.622220  0.604478   0.888889  0.290152
# 18  0.521370  1.000000   0.444444  0.000000
# 19  0.436307  0.578358   0.703704  0.145723
# 20  0.445335  0.391791   0.148148  0.057740
# 21  0.320145  0.660448   0.185185  0.085185
# 22  0.209543  0.761194   0.000000  0.235473
# 23  0.000000  0.888060   0.000000  0.350241
# 24  0.055185  0.783582   0.629630  0.536234

# %%
s_corr_df = scaled_df.corr()
s_corr_df = s_corr_df.apply(lambda x: round(x,2))
s_corr_df
# Out:
#            인구수평균  전기차 변수  태양광 발전소 수  풍력 비율
# 인구수평균       1.00   -0.71       0.41   0.33
# 전기차 변수     -0.71    1.00      -0.30  -0.64
# 태양광 발전소 수   0.41   -0.30       1.00   0.06
# 풍력 비율       0.33   -0.64       0.06   1.00

# %%
fig, ax = plt.subplots()
im = ax.imshow(s_corr_df, cmap='GnBu')

cbar = ax.figure.colorbar(im, ax=ax)

ax.set_xticks(np.arange(len(s_corr_df.columns)))
ax.set_yticks(np.arange(len(s_corr_df.index)))

ax.set_xticklabels(s_corr_df.columns,rotation='40')
ax.set_yticklabels(s_corr_df.columns)

for x in range(len(s_corr_df.columns)):
    for y in range(len(s_corr_df.index)):
        ax.text(y,x,s_corr_df.iloc[y,x],ha='center',va='center',color='black')
       
fig.tight_layout()
plt.show()

# %%
# scaled_df['인구수평균'] = np.array(ppl_scaled).flatten().tolist()
# scaled_df['충전소 수'] = np.array(charger_scaled).flatten().tolist()
# scaled_df['전기차 수'] = np.array(car_scaled).flatten().tolist()
# #scaled_df['전기차 변수'] = np.array(ref_scaled).flatten().tolist()
# scaled_df['태양광 발전소 수'] = np.array(sol_scaled).flatten().tolist()
# scaled_df['전기사용량 평균'] = np.array(elec_scaled).flatten().tolist()
import math

k = 1/(math.log(25)) #k=1/(ln(m)
ppl_scaled_list = np.array(ppl_scaled).flatten().tolist()
#entropy_ppl = []
ppl_ent = 0

for i in ppl_scaled_list:
    try:
        ppl_ent = ppl_ent+(i*math.log(i))
    except ValueError:
        ppl_ent = ppl_ent+0

ppl_ent = (-k)*ppl_ent
ppl_div = 1-ppl_ent
ppl_div
# Out:
# -1.1367601133239038

# %%
charger_scaled_list = np.array(charger_scaled).flatten().tolist()
charger_ent = 0

for i in charger_scaled_list:
    try:
        charger_ent = charger_ent+(i*math.log(i))
    except ValueError:
        charger_ent = charger_ent+0

charger_ent = (-k)*charger_ent
charger_div = 1-charger_ent
charger_div
# Out:
# -1.2331708278851758

# %%
car_scaled_list = np.array(car_scaled).flatten().tolist()
car_ent = 0

for i in car_scaled_list:
    try:
        car_ent = car_ent+(i*math.log(i))
    except ValueError:
        car_ent = car_ent+0

car_ent = (-k)*car_ent
car_div = 1-car_ent
car_div
# Out:
# -0.6796112518054578

# %%
sol_scaled_list = np.array(sol_scaled).flatten().tolist()
sol_ent = 0

for i in sol_scaled_list:
    try:
        sol_ent = sol_ent+(i*math.log(i))
    except ValueError:
        sol_ent = sol_ent+0

sol_ent = (-k)*sol_ent
sol_div = 1-sol_ent
sol_div
# Out:
# -0.9038012279887973

# %%
ref_scaled_list = np.array(ref_scaled).flatten().tolist()
ref_ent = 0

for i in ref_scaled_list:
    try:
        ref_ent = ref_ent+(i*math.log(i))
    except ValueError:
        ref_ent = ref_ent+0

ref_ent = (-k)*ref_ent
ref_div = 1-ref_ent
ref_div
# Out:
# -1.082202784625066

# %%
wind_scaled_list = np.array(wind_scaled).flatten().tolist()
wind_ent = 0

for i in wind_scaled_list:
    try:
        wind_ent = wind_ent+(i*math.log(i))
    except ValueError:
        wind_ent = wind_ent+0

wind_ent = (-k)*wind_ent
wind_div = 1-wind_ent
wind_div
# Out:
# -0.5489096845063701

# %%
#전기차 변수 가중치
ref_w = ref_div/(sol_div+ref_div+ppl_div+wind_div)

# %%
#인구 수 가중치
ppl_w  = ppl_div/(sol_div+ref_div+ppl_div+wind_div)

# %%
#태양광 수 가중치
sol_w = sol_div/(sol_div+ref_div+ppl_div+wind_div)

# %%
#풍속 가중치
wind_w = wind_div/(sol_div+ref_div+ppl_div+wind_div)

# %%
print("전기 차 변수 가중치:{}".format(round(ref_w,2)))
print("인구 수 변수 가중치:{}".format(round(ppl_w,2)))
print("태양광 변수 가중치:{}".format(round(sol_w,2)))
print("풍속 변수 가중치:{}".format(round(wind_w,2)))
# Out:
# 전기 차 변수 가중치:0.29
# 인구 수 변수 가중치:0.31
# 태양광 변수 가중치:0.25
# 풍속 변수 가중치:0.15
